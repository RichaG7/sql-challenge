# %%
from sqlalchemy import create_engine, inspect
from sqlalchemy.orm import Session
from sqlalchemy.ext.automap import automap_base

from sqlalchemy import Column, Integer, String, Float

import matplotlib.pyplot as plt

import pandas as pd

engine = create_engine('postgresql://localhost:5432/employee_db')
connection = engine.connect()

# %%
inspector = inspect(engine)

# %%
inspector.get_table_names()
# Out:
# ['departments', 'dept_emp', 'dept_manager', 'employees', 'salaries', 'titles']

# %%
columns_salaries = inspector.get_columns('salaries')
for column in columns_salaries:
    print(column["name"], column["type"])
# Out:
# emp_no INTEGER
# salary INTEGER
# from_date DATE
# to_date DATE

# %%
columns_titles = inspector.get_columns('titles')
for column in columns_titles:
    print(column["name"], column["type"])
# Out:
# emp_no INTEGER
# title VARCHAR
# from_date DATE
# to_date DATE

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)

# %%
Salaries = Base.classes.salaries
Titles = Base.classes.titles

# %%
session = Session(engine)

# %%
sel = [Salaries.emp_no, Salaries.salary, Salaries.from_date, Salaries.to_date, Titles.title, Titles.from_date, Titles.to_date]
merge = session.query(*sel).filter(Salaries.emp_no == Titles.emp_no and Salaries.from_date == Titles.from_date).all()

merge
# Out:
# [(10005,
#   78228,
#   datetime.date(1989, 9, 12),
#   datetime.date(1990, 9, 12),
#   'Senior Staff',
#   datetime.date(1996, 9, 12),
#   datetime.date(9999, 1, 1)),
#  (10005,
#   78228,
#   datetime.date(1989, 9, 12),
#   datetime.date(1990, 9, 12),
#   'Staff',
#   datetime.date(1989, 9, 12),
#   datetime.date(1996, 9, 12)),
#  (10010,
#   72488,
#   datetime.date(1996, 11, 24),
#   datetime.date(1997, 11, 24),
#   'Engineer',
#   datetime.date(1996, 11, 24),
#   datetime.date(9999, 1, 1)),
#  (10011,
#   42365,
#   datetime.date(1990, 1, 22),
#   datetime.date(1991, 1, 22),
#   'Staff',
#   datetime.date(1990, 1, 22),
#   datetime.date(1996, 11, 9)),
#  (10018,
#   55881,
#   datetime.date(1987, 4, 3),
#   datetime.date(1988, 4, 2),
#   'Engineer',
#   datetime.date(1987, 4, 3),
#   datetime.date(1995, 4, 3)),
#  (10018,
#   55881,
#   datetime.date(1987, 4, 3),
#   datetime.date(1988, 4, 2),
#   'Senior Engineer',
#   datetime.date(1995, 4, 3),
#   datetime.date(9999, 1, 1)),
#  (10035,
#   41538,
#   datetime.date(1988, 9, 5),
#   datetime.date(1989, 9, 5),
#   'Engineer',
#   datetime.date(1988, 9, 5),
#   datetime.date(1996, 9, 5)),
#  (10035,
#   41538,
#   datetime.date(1988, 9, 5),
#   datetime.date(1989, 9, 5),
#   'Senior Engineer',
#   datetime.date(1996, 9, 5),
#   datetime.date(9999, 1, 1)),
#  (10043,
#   49324,
#   datetime.date(1990, 10, 20),
#   datetime.date(1991, 10, 20),
#   'Engineer',
#   datetime.date(1990, 10, 20),
#   datetime.date(1997, 10, 20)),
#  (10043,
#   49324,
#   datetime.date(1990, 10, 20),
#   datetime.date(1991, 10, 20),
#   'Senior Engineer',
#   datetime.date(1997, 10, 20),
#   datetime.date(9999, 1, 1)),
#  (10045,
#   41971,
#   datetime.date(1996, 11, 16),
#   datetime.date(1997, 11, 16),
#   'Engineer',
#   datetime.date(1996, 11, 16),
#   datetime.date(9999, 1, 1)),
#  (10058,
#   52787,
#   datetime.date(1988, 4, 25),
#   datetime.date(1989, 4, 25),
#   'Senior Staff',
#   datetime.date(1988, 4, 25),
#   datetime.date(9999, 1, 1)),
#  (10078,
#   47280,
#   datetime.date(1994, 9, 29),
#   datetime.date(1995, 9, 29),
#   'Engineer',
#   datetime.date(1994, 9, 29),
#   datetime.date(9999, 1, 1)),
#  (10081,
#   55786,
#   datetime.date(1986, 10, 30),
#   datetime.date(1987, 10, 30),
#   'Engineer',
#   datetime.date(1986, 10, 30),
#   datetime.date(1991, 10, 30)),
#  (10081,
#   55786,
#   datetime.date(1986, 10, 30),
#   datetime.date(1987, 10, 30),
#   'Senior Engineer',
#   datetime.date(1991, 10, 30),
#   datetime.date(9999, 1, 1)),
#  (10085,
#   40000,
#   datetime.date(1994, 4, 9),
#   datetime.date(1995, 4, 9),
#   'Senior Engineer',
#   datetime.date(1994, 4, 9),
#   datetime.date(9999, 1, 1)),
#  (10096,
#   61395,
#   datetime.date(1999, 1, 23),
#   datetime.date(2000, 1, 23),
#   'Engineer',
#   datetime.date(1999, 1, 23),
#   datetime.date(9999, 1, 1)),
#  (10104,
#   45312,
#   datetime.date(1987, 4, 16),
#   datetime.date(1988, 4, 15),
#   'Senior Staff',
#   datetime.date(1987, 4, 16),
#   datetime.date(9999, 1, 1)),
#  (10126,
#   40000,
#   datetime.date(1985, 9, 8),
#   datetime.date(1986, 9, 8),
#   'Senior Staff',
#   datetime.date(1991, 9, 8),
#   datetime.date(9999, 1, 1)),
#  (10126,
#   40000,
#   datetime.date(1985, 9, 8),
#   datetime.date(1986, 9, 8),
#   'Staff',
#   datetime.date(1985, 9, 8),
#   datetime.date(1991, 9, 8)),
#  (10167,
#   56990,
#   datetime.date(1992, 4, 4),
#   datetime.date(1993, 4, 4),
#   'Engineer',
#   datetime.date(1992, 4, 4),
#   datetime.date(2001, 4, 4)),
#  (10167,
#   56990,
#   datetime.date(1992, 4, 4),
#   datetime.date(1993, 4, 4),
#   'Senior Engineer',
#   datetime.date(2001, 4, 4),
#   datetime.date(9999, 1, 1)),
#  (10176,
#   54635,
#   datetime.date(1994, 12, 22),
#   datetime.date(1995, 12, 22),
#   'Senior Staff',
#   datetime.date(1999, 12, 22),
#   datetime.date(9999, 1, 1)),
#  (10176,
#   54635,
#   datetime.date(1994, 12, 22),
#   datetime.date(1995, 12, 22),
#   'Staff',
#   datetime.date(1994, 12, 22),
#   datetime.date(1999, 12, 22)),
#  (10178,
#   50568,
#   datetime.date(1994, 3, 21),
#   datetime.date(1995, 3, 21),
#   'Staff',
#   datetime.date(1994, 3, 21),
#   datetime.date(9999, 1, 1)),
#  (10181,
#   40000,
#   datetime.date(1988, 6, 22),
#   datetime.date(1989, 6, 22),
#   'Senior Engineer',
#   datetime.date(1988, 6, 22),
#   datetime.date(9999, 1, 1)),
#  (10185,
#   68334,
#   datetime.date(1986, 3, 1),
#   datetime.date(1987, 3, 1),
#   'Senior Staff',
#   datetime.date(1992, 2, 29),
#   datetime.date(9999, 1, 1)),
#  (10185,
#   68334,
#   datetime.date(1986, 3, 1),
#   datetime.date(1987, 3, 1),
#   'Staff',
#   datetime.date(1986, 3, 1),
#   datetime.date(1992, 2, 29)),
#  (10228,
#   79474,
#   datetime.date(1992, 12, 22),
#   datetime.date(1993, 12, 22),
#   'Senior Staff',
#   datetime.date(1998, 12, 22),
#   datetime.date(9999, 1, 1)),
#  (10228,
#   79474,
#   datetime.date(1992, 12, 22),
#   datetime.date(1993, 12, 22),
#   'Staff',
#   datetime.date(1992, 12, 22),
#   datetime.date(1998, 12, 22)),
#  (10231,
#   40000,
#   datetime.date(1998, 9, 9),
#   datetime.date(1999, 9, 9),
#   'Staff',
#   datetime.date(1998, 9, 9),
#   datetime.date(9999, 1, 1)),
#  (10232,
#   89606,
#   datetime.date(1992, 6, 4),
#   datetime.date(1993, 6, 4),
#   'Senior Staff',
#   datetime.date(1998, 6, 4),
#   datetime.date(9999, 1, 1)),
#  (10232,
#   89606,
#   datetime.date(1992, 6, 4),
#   datetime.date(1993, 6, 4),
#   'Staff',
#   datetime.date(1992, 6, 4),
#   datetime.date(1998, 6, 4)),
#  (10244,
#   56292,
#   datetime.date(1999, 9, 16),
#   datetime.date(2000, 9, 15),
#   'Engineer',
#   datetime.date(1999, 9, 16),
#   datetime.date(9999, 1, 1)),
#  (10250,
#   50330,
#   datetime.date(1992, 8, 30),
#   datetime.date(1993, 8, 30),
#   'Engineer',
#   datetime.date(1992, 8, 30),
#   datetime.date(2001, 8, 30)),
#  (10250,
#   50330,
#   datetime.date(1992, 8, 30),
#   datetime.date(1993, 8, 30),
#   'Senior Engineer',
#   datetime.date(2001, 8, 30),
#   datetime.date(9999, 1, 1)),
#  (10267,
#   40000,
#   datetime.date(1997, 4, 26),
#   datetime.date(1998, 4, 26),
#   'Engineer',
#   datetime.date(1997, 4, 26),
#   datetime.date(9999, 1, 1)),
#  (10278,
#   51703,
#   datetime.date(1993, 7, 2),
#   datetime.date(1994, 7, 2),
#   'Engineer',
#   datetime.date(1993, 7, 2),
#   datetime.date(1997, 2, 14)),
#  (10279,
#   40000,
#   datetime.date(1995, 4, 26),
#   datetime.date(1996, 4, 25),
#   'Engineer',
#   datetime.date(1995, 4, 26),
#   datetime.date(9999, 1, 1)),
#  (10302,
#   58239,
#   datetime.date(1986, 7, 22),
#   datetime.date(1987, 7, 22),
#   'Senior Staff',
#   datetime.date(1994, 7, 22),
#   datetime.date(1999, 11, 9)),
#  (10302,
#   58239,
#   datetime.date(1986, 7, 22),
#   datetime.date(1987, 7, 22),
#   'Staff',
#   datetime.date(1986, 7, 22),
#   datetime.date(1994, 7, 22)),
#  (10303,
#   40000,
#   datetime.date(1990, 2, 5),
#   datetime.date(1991, 2, 5),
#   'Senior Engineer',
#   datetime.date(1990, 2, 5),
#   datetime.date(2000, 11, 15)),
#  (10312,
#   56705,
#   datetime.date(1986, 8, 28),
#   datetime.date(1987, 8, 28),
#   'Senior Engineer',
#   datetime.date(1986, 8, 28),
#   datetime.date(9999, 1, 1)),
#  (10317,
#   51129,
#   datetime.date(1999, 1, 24),
#   datetime.date(2000, 1, 24),
#   'Staff',
#   datetime.date(1999, 1, 24),
#   datetime.date(9999, 1, 1)),
#  (10320,
#   58483,
#   datetime.date(1988, 11, 3),
#   datetime.date(1989, 11, 3),
#   'Senior Staff',
#   datetime.date(1996, 11, 3),
#   datetime.date(2001, 12, 23)),
#  (10320,
#   58483,
#   datetime.date(1988, 11, 3),
#   datetime.date(1989, 11, 3),
#   'Staff',
#   datetime.date(1988, 11, 3),
#   datetime.date(1996, 11, 3)),
#  (10340,
#   68132,
#   datetime.date(1988, 3, 30),
#   datetime.date(1989, 3, 30),
#   'Senior Staff',
#   datetime.date(1993, 3, 30),
#   datetime.date(9999, 1, 1)),
#  (10340,
#   68132,
#   datetime.date(1988, 3, 30),
#   datetime.date(1989, 3, 30),
#   'Staff',
#   datetime.date(1988, 3, 30),
#   datetime.date(1993, 3, 30)),
#  (10353,
#   62656,
#   datetime.date(1989, 8, 24),
#   datetime.date(1990, 8, 24),
#   'Senior Staff',
#   datetime.date(1989, 8, 24),
#   datetime.date(9999, 1, 1)),
#  (10362,
#   40000,
#   datetime.date(1990, 11, 2),
#   datetime.date(1991, 11, 2),
#   'Senior Staff',
#   datetime.date(1990, 11, 2),
#   datetime.date(1997, 7, 16)),
#  (10364,
#   51401,
#   datetime.date(1985, 11, 14),
#   datetime.date(1986, 11, 14),
#   'Senior Engineer',
#   datetime.date(1985, 11, 14),
#   datetime.date(9999, 1, 1)),
#  (10366,
#   47229,
#   datetime.date(1997, 8, 15),
#   datetime.date(1998, 8, 15),
#   'Engineer',
#   datetime.date(1997, 8, 15),
#   datetime.date(9999, 1, 1)),
#  (10381,
#   78510,
#   datetime.date(1991, 12, 4),
#   datetime.date(1992, 12, 3),
#   'Assistant Engineer',
#   datetime.date(1991, 12, 4),
#   datetime.date(2000, 12, 3)),
#  (10381,
#   78510,
#   datetime.date(1991, 12, 4),
#   datetime.date(1992, 12, 3),
#   'Engineer',
#   datetime.date(2000, 12, 3),
#   datetime.date(9999, 1, 1)),
#  (10387,
#   61374,
#   datetime.date(1994, 1, 7),
#   datetime.date(1995, 1, 7),
#   'Senior Staff',
#   datetime.date(1999, 1, 7),
#   datetime.date(9999, 1, 1)),
#  (10387,
#   61374,
#   datetime.date(1994, 1, 7),
#   datetime.date(1995, 1, 7),
#   'Staff',
#   datetime.date(1994, 1, 7),
#   datetime.date(1999, 1, 7)),
#  (10394,
#   40000,
#   datetime.date(1991, 3, 14),
#   datetime.date(1991, 8, 25),
#   'Engineer',
#   datetime.date(1991, 3, 14),
#   datetime.date(1991, 8, 25)),
#  (10396,
#   40393,
#   datetime.date(1986, 1, 11),
#   datetime.date(1987, 1, 11),
#   'Senior Engineer',
#   datetime.date(1986, 1, 11),
#   datetime.date(9999, 1, 1)),
#  (10416,
#   68993,
#   datetime.date(1989, 3, 24),
#   datetime.date(1990, 3, 24),
#   'Senior Staff',
#   datetime.date(1996, 3, 24),
#   datetime.date(9999, 1, 1)),
#  (10416,
#   68993,
#   datetime.date(1989, 3, 24),
#   datetime.date(1990, 3, 24),
#   'Staff',
#   datetime.date(1989, 3, 24),
#   datetime.date(1996, 3, 24)),
#  (10428,
#   40000,
#   datetime.date(1992, 6, 4),
#   datetime.date(1993, 6, 4),
#   'Senior Staff',
#   datetime.date(1999, 6, 5),
#   datetime.date(9999, 1, 1)),
#  (10428,
#   40000,
#   datetime.date(1992, 6, 4),
#   datetime.date(1993, 6, 4),
#   'Staff',
#   datetime.date(1992, 6, 4),
#   datetime.date(1999, 6, 5)),
#  (10430,
#   40000,
#   datetime.date(1998, 7, 5),
#   datetime.date(1999, 7, 5),
#   'Senior Engineer',
#   datetime.date(1998, 7, 5),
#   datetime.date(9999, 1, 1)),
#  (10434,
#   40000,
#   datetime.date(1995, 6, 27),
#   datetime.date(1996, 6, 26),
#   'Engineer',
#   datetime.date(1995, 6, 27),
#   datetime.date(2001, 6, 26)),
#  (10434,
#   40000,
#   datetime.date(1995, 6, 27),
#   datetime.date(1996, 6, 26),
#   'Senior Engineer',
#   datetime.date(2001, 6, 26),
#   datetime.date(2002, 6, 22)),
#  (10450,
#   40000,
#   datetime.date(1997, 8, 24),
#   datetime.date(1998, 8, 24),
#   'Engineer',
#   datetime.date(1997, 8, 24),
#   datetime.date(9999, 1, 1)),
#  (10453,
#   40000,
#   datetime.date(1985, 4, 2),
#   datetime.date(1986, 4, 2),
#   'Senior Staff',
#   datetime.date(1993, 4, 2),
#   datetime.date(9999, 1, 1)),
#  (10453,
#   40000,
#   datetime.date(1985, 4, 2),
#   datetime.date(1986, 4, 2),
#   'Staff',
#   datetime.date(1985, 4, 2),
#   datetime.date(1993, 4, 2)),
#  (10456,
#   57599,
#   datetime.date(2000, 1, 6),
#   datetime.date(2001, 1, 5),
#   'Staff',
#   datetime.date(2000, 1, 6),
#   datetime.date(9999, 1, 1)),
#  (10471,
#   58951,
#   datetime.date(1990, 11, 18),
#   datetime.date(1991, 11, 18),
#   'Senior Engineer',
#   datetime.date(1990, 11, 18),
#   datetime.date(9999, 1, 1)),
#  (10475,
#   51203,
#   datetime.date(1992, 5, 13),
#   datetime.date(1993, 5, 13),
#   'Engineer',
#   datetime.date(1992, 5, 13),
#   datetime.date(1994, 12, 30)),
#  (10476,
#   58221,
#   datetime.date(1987, 9, 20),
#   datetime.date(1988, 9, 19),
#   'Senior Staff',
#   datetime.date(1994, 9, 20),
#   datetime.date(9999, 1, 1)),
#  (10476,
#   58221,
#   datetime.date(1987, 9, 20),
#   datetime.date(1988, 9, 19),
#   'Staff',
#   datetime.date(1987, 9, 20),
#   datetime.date(1994, 9, 20)),
#  (10480,
#   55669,
#   datetime.date(1988, 5, 18),
#   datetime.date(1989, 5, 18),
#   'Staff',
#   datetime.date(1988, 5, 18),
#   datetime.date(1989, 6, 3)),
#  (10489,
#   56739,
#   datetime.date(1989, 9, 10),
#   datetime.date(1989, 10, 6),
#   'Engineer',
#   datetime.date(1989, 9, 10),
#   datetime.date(1989, 10, 6)),
#  (10494,
#   50094,
#   datetime.date(1991, 12, 18),
#   datetime.date(1992, 12, 17),
#   'Engineer',
#   datetime.date(1991, 12, 18),
#   datetime.date(2000, 12, 17)),
#  (10494,
#   50094,
#   datetime.date(1991, 12, 18),
#   datetime.date(1992, 12, 17),
#   'Senior Engineer',
#   datetime.date(2000, 12, 17),
#   datetime.date(9999, 1, 1)),
#  (10501,
#   53922,
#   datetime.date(1988, 9, 8),
#   datetime.date(1989, 9, 8),
#   'Engineer',
#   datetime.date(1988, 9, 8),
#   datetime.date(1995, 9, 9)),
#  (10501,
#   53922,
#   datetime.date(1988, 9, 8),
#   datetime.date(1989, 9, 8),
#   'Senior Engineer',
#   datetime.date(1995, 9, 9),
#   datetime.date(9999, 1, 1)),
#  (10513,
#   86392,
#   datetime.date(1991, 4, 2),
#   datetime.date(1992, 4, 1),
#   'Senior Staff',
#   datetime.date(1997, 4, 1),
#   datetime.date(9999, 1, 1)),
#  (10513,
#   86392,
#   datetime.date(1991, 4, 2),
#   datetime.date(1992, 4, 1),
#   'Staff',
#   datetime.date(1991, 4, 2),
#   datetime.date(1997, 4, 1)),
#  (10515,
#   91484,
#   datetime.date(1990, 1, 6),
#   datetime.date(1991, 1, 6),
#   'Senior Staff',
#   datetime.date(1997, 1, 6),
#   datetime.date(1998, 7, 21)),
#  (10515,
#   91484,
#   datetime.date(1990, 1, 6),
#   datetime.date(1991, 1, 6),
#   'Staff',
#   datetime.date(1990, 1, 6),
#   datetime.date(1997, 1, 6)),
#  (10517,
#   65330,
#   datetime.date(1990, 12, 25),
#   datetime.date(1991, 12, 25),
#   'Senior Staff',
#   datetime.date(1990, 12, 25),
#   datetime.date(9999, 1, 1)),
#  (10519,
#   40000,
#   datetime.date(1992, 12, 5),
#   datetime.date(1993, 12, 5),
#   'Senior Staff',
#   datetime.date(2000, 12, 5),
#   datetime.date(2001, 10, 13)),
#  (10519,
#   40000,
#   datetime.date(1992, 12, 5),
#   datetime.date(1993, 12, 5),
#   'Staff',
#   datetime.date(1992, 12, 5),
#   datetime.date(2000, 12, 5)),
#  (10527,
#   43405,
#   datetime.date(1996, 1, 25),
#   datetime.date(1997, 1, 24),
#   'Technique Leader',
#   datetime.date(1996, 1, 25),
#   datetime.date(9999, 1, 1)),
#  (10543,
#   86526,
#   datetime.date(1998, 11, 24),
#   datetime.date(1999, 11, 24),
#   'Staff',
#   datetime.date(1998, 11, 24),
#   datetime.date(9999, 1, 1)),
#  (10548,
#   90631,
#   datetime.date(1986, 7, 4),
#   datetime.date(1987, 7, 4),
#   'Senior Staff',
#   datetime.date(1993, 7, 4),
#   datetime.date(9999, 1, 1)),
#  (10548,
#   90631,
#   datetime.date(1986, 7, 4),
#   datetime.date(1987, 7, 4),
#   'Staff',
#   datetime.date(1986, 7, 4),
#   datetime.date(1993, 7, 4)),
#  (10557,
#   43289,
#   datetime.date(1992, 9, 18),
#   datetime.date(1993, 9, 18),
#   'Engineer',
#   datetime.date(1992, 9, 18),
#   datetime.date(2001, 9, 18)),
#  (10557,
#   43289,
#   datetime.date(1992, 9, 18),
#   datetime.date(1993, 9, 18),
#   'Senior Engineer',
#   datetime.date(2001, 9, 18),
#   datetime.date(9999, 1, 1)),
#  (10559,
#   90120,
#   datetime.date(1999, 4, 5),
#   datetime.date(2000, 4, 4),
#   'Staff',
#   datetime.date(1999, 4, 5),
#   datetime.date(9999, 1, 1)),
#  (10581,
#   46569,
#   datetime.date(1994, 4, 13),
#   datetime.date(1995, 4, 13),
#   'Engineer',
#   datetime.date(1994, 4, 13),
#   datetime.date(1999, 4, 13)),
#  (10581,
#   46569,
#   datetime.date(1994, 4, 13),
#   datetime.date(1995, 4, 13),
#   'Senior Engineer',
#   datetime.date(1999, 4, 13),
#   datetime.date(9999, 1, 1)),
#  (10588,
#   41478,
#   datetime.date(1988, 7, 25),
#   datetime.date(1989, 7, 25),
#   'Engineer',
#   datetime.date(1988, 7, 25),
#   datetime.date(1993, 7, 25)),
#  (10588,
#   41478,
#   datetime.date(1988, 7, 25),
#   datetime.date(1989, 7, 25),
#   'Senior Engineer',
#   datetime.date(1993, 7, 25),
#   datetime.date(9999, 1, 1)),
#  (10591,
#   55131,
#   datetime.date(1987, 6, 18),
#   datetime.date(1988, 6, 17),
#   'Staff',
#   datetime.date(1987, 6, 18),
#   datetime.date(1988, 9, 20)),
#  (10595,
#   40000,
#   datetime.date(1989, 11, 24),
#   datetime.date(1990, 11, 24),
#   'Senior Engineer',
#   datetime.date(1989, 11, 24),
#   datetime.date(9999, 1, 1)),
#  (10612,
#   40000,
#   datetime.date(1991, 9, 2),
#   datetime.date(1992, 9, 1),
#   'Assistant Engineer',
#   datetime.date(1991, 9, 2),
#   datetime.date(1996, 9, 1)),
#  (10612,
#   40000,
#   datetime.date(1991, 9, 2),
#   datetime.date(1992, 9, 1),
#   'Engineer',
#   datetime.date(1996, 9, 1),
#   datetime.date(2001, 9, 1)),
#  (10612,
#   40000,
#   datetime.date(1991, 9, 2),
#   datetime.date(1992, 9, 1),
#   'Senior Engineer',
#   datetime.date(2001, 9, 1),
#   datetime.date(9999, 1, 1)),
#  (10614,
#   40000,
#   datetime.date(1990, 3, 3),
#   datetime.date(1991, 3, 3),
#   'Engineer',
#   datetime.date(1990, 3, 3),
#   datetime.date(1998, 3, 3)),
#  (10614,
#   40000,
#   datetime.date(1990, 3, 3),
#   datetime.date(1991, 3, 3),
#   'Senior Engineer',
#   datetime.date(1998, 3, 3),
#   datetime.date(9999, 1, 1)),
#  (10622,
#   40000,
#   datetime.date(1989, 5, 15),
#   datetime.date(1990, 5, 15),
#   'Engineer',
#   datetime.date(1989, 5, 15),
#   datetime.date(1996, 5, 15)),
#  (10622,
#   40000,
#   datetime.date(1989, 5, 15),
#   datetime.date(1990, 5, 15),
#   'Senior Engineer',
#   datetime.date(1996, 5, 15),
#   datetime.date(9999, 1, 1)),
#  (10626,
#   40000,
#   datetime.date(1996, 12, 3),
#   datetime.date(1997, 12, 3),
#   'Staff',
#   datetime.date(1996, 12, 3),
#   datetime.date(9999, 1, 1)),
#  (10628,
#   41650,
#   datetime.date(1987, 3, 14),
#   datetime.date(1988, 3, 13),
#   'Assistant Engineer',
#   datetime.date(1987, 3, 14),
#   datetime.date(1994, 3, 14)),
#  (10628,
#   41650,
#   datetime.date(1987, 3, 14),
#   datetime.date(1988, 3, 13),
#   'Engineer',
#   datetime.date(1994, 3, 14),
#   datetime.date(2001, 3, 14)),
#  (10628,
#   41650,
#   datetime.date(1987, 3, 14),
#   datetime.date(1988, 3, 13),
#   'Senior Engineer',
#   datetime.date(2001, 3, 14),
#   datetime.date(9999, 1, 1)),
#  (10645,
#   40000,
#   datetime.date(1988, 3, 1),
#   datetime.date(1989, 3, 1),
#   'Engineer',
#   datetime.date(1988, 3, 1),
#   datetime.date(1995, 3, 2)),
#  (10645,
#   40000,
#   datetime.date(1988, 3, 1),
#   datetime.date(1989, 3, 1),
#   'Senior Engineer',
#   datetime.date(1995, 3, 2),
#   datetime.date(9999, 1, 1)),
#  (10651,
#   42023,
#   datetime.date(1996, 1, 8),
#   datetime.date(1997, 1, 7),
#   'Senior Staff',
#   datetime.date(2002, 1, 7),
#   datetime.date(9999, 1, 1)),
#  (10651,
#   42023,
#   datetime.date(1996, 1, 8),
#   datetime.date(1997, 1, 7),
#   'Staff',
#   datetime.date(1996, 1, 8),
#   datetime.date(2002, 1, 7)),
#  (10652,
#   53160,
#   datetime.date(1990, 2, 12),
#   datetime.date(1991, 2, 12),
#   'Staff',
#   datetime.date(1990, 2, 12),
#   datetime.date(1992, 1, 13)),
#  (10669,
#   40000,
#   datetime.date(1996, 11, 17),
#   datetime.date(1997, 11, 17),
#   'Senior Staff',
#   datetime.date(2001, 11, 17),
#   datetime.date(9999, 1, 1)),
#  (10669,
#   40000,
#   datetime.date(1996, 11, 17),
#   datetime.date(1997, 11, 17),
#   'Staff',
#   datetime.date(1996, 11, 17),
#   datetime.date(2001, 11, 17)),
#  (10672,
#   64663,
#   datetime.date(1991, 9, 29),
#   datetime.date(1992, 9, 28),
#   'Senior Engineer',
#   datetime.date(1991, 9, 29),
#   datetime.date(1996, 4, 19)),
#  (10677,
#   56994,
#   datetime.date(1999, 10, 13),
#   datetime.date(2000, 10, 12),
#   'Engineer',
#   datetime.date(1999, 10, 13),
#   datetime.date(9999, 1, 1)),
#  (10678,
#   60389,
#   datetime.date(1987, 8, 2),
#   datetime.date(1988, 8, 1),
#   'Engineer',
#   datetime.date(1987, 8, 2),
#   datetime.date(1995, 8, 2)),
#  (10678,
#   60389,
#   datetime.date(1987, 8, 2),
#   datetime.date(1988, 8, 1),
#   'Senior Engineer',
#   datetime.date(1995, 8, 2),
#   datetime.date(9999, 1, 1)),
#  (10696,
#   68913,
#   datetime.date(1991, 9, 9),
#   datetime.date(1992, 9, 8),
#   'Technique Leader',
#   datetime.date(1991, 9, 9),
#   datetime.date(9999, 1, 1)),
#  (10700,
#   41400,
#   datetime.date(1998, 4, 14),
#   datetime.date(1999, 4, 14),
#   'Engineer',
#   datetime.date(1998, 4, 14),
#   datetime.date(2002, 6, 27)),
#  (10716,
#   44101,
#   datetime.date(1987, 8, 12),
#   datetime.date(1988, 8, 11),
#   'Engineer',
#   datetime.date(1987, 8, 12),
#   datetime.date(1993, 8, 11)),
#  (10716,
#   44101,
#   datetime.date(1987, 8, 12),
#   datetime.date(1988, 8, 11),
#   'Senior Engineer',
#   datetime.date(1993, 8, 11),
#   datetime.date(9999, 1, 1)),
#  (10720,
#   45832,
#   datetime.date(1996, 6, 26),
#   datetime.date(1997, 6, 26),
#   'Senior Staff',
#   datetime.date(1996, 6, 26),
#   datetime.date(9999, 1, 1)),
#  (10723,
#   40000,
#   datetime.date(1997, 7, 14),
#   datetime.date(1998, 7, 14),
#   'Technique Leader',
#   datetime.date(1997, 7, 14),
#   datetime.date(9999, 1, 1)),
#  (10725,
#   79207,
#   datetime.date(1990, 9, 8),
#   datetime.date(1991, 9, 8),
#   'Senior Staff',
#   datetime.date(1990, 9, 8),
#   datetime.date(9999, 1, 1)),
#  (10733,
#   48013,
#   datetime.date(1996, 2, 20),
#   datetime.date(1997, 2, 19),
#   'Senior Staff',
#   datetime.date(2002, 2, 19),
#   datetime.date(9999, 1, 1)),
#  (10733,
#   48013,
#   datetime.date(1996, 2, 20),
#   datetime.date(1997, 2, 19),
#   'Staff',
#   datetime.date(1996, 2, 20),
#   datetime.date(2002, 2, 19)),
#  (10737,
#   73505,
#   datetime.date(1999, 6, 22),
#   datetime.date(2000, 6, 21),
#   'Engineer',
#   datetime.date(1999, 6, 22),
#   datetime.date(9999, 1, 1)),
#  (10741,
#   50265,
#   datetime.date(1989, 1, 6),
#   datetime.date(1990, 1, 6),
#   'Senior Staff',
#   datetime.date(1997, 1, 6),
#   datetime.date(9999, 1, 1)),
#  (10741,
#   50265,
#   datetime.date(1989, 1, 6),
#   datetime.date(1990, 1, 6),
#   'Staff',
#   datetime.date(1989, 1, 6),
#   datetime.date(1997, 1, 6)),
#  (10748,
#   54532,
#   datetime.date(1990, 8, 14),
#   datetime.date(1991, 8, 14),
#   'Senior Staff',
#   datetime.date(1996, 8, 13),
#   datetime.date(9999, 1, 1)),
#  (10748,
#   54532,
#   datetime.date(1990, 8, 14),
#   datetime.date(1991, 8, 14),
#   'Staff',
#   datetime.date(1990, 8, 14),
#   datetime.date(1996, 8, 13)),
#  (10753,
#   59507,
#   datetime.date(1985, 5, 17),
#   datetime.date(1986, 5, 17),
#   'Engineer',
#   datetime.date(1985, 5, 17),
#   datetime.date(1993, 5, 17)),
#  (10753,
#   59507,
#   datetime.date(1985, 5, 17),
#   datetime.date(1986, 5, 17),
#   'Senior Engineer',
#   datetime.date(1993, 5, 17),
#   datetime.date(1999, 8, 25)),
#  (10758,
#   54186,
#   datetime.date(1999, 7, 1),
#   datetime.date(2000, 6, 30),
#   'Engineer',
#   datetime.date(1999, 7, 1),
#   datetime.date(9999, 1, 1)),
#  (10760,
#   40000,
#   datetime.date(1997, 8, 22),
#   datetime.date(1998, 8, 22),
#   'Senior Staff',
#   datetime.date(1997, 8, 22),
#   datetime.date(9999, 1, 1)),
#  (10762,
#   52172,
#   datetime.date(1992, 1, 21),
#   datetime.date(1993, 1, 20),
#   'Senior Staff',
#   datetime.date(1999, 1, 21),
#   datetime.date(9999, 1, 1)),
#  (10762,
#   52172,
#   datetime.date(1992, 1, 21),
#   datetime.date(1993, 1, 20),
#   'Staff',
#   datetime.date(1992, 1, 21),
#   datetime.date(1999, 1, 21)),
#  (10770,
#   63401,
#   datetime.date(1987, 12, 25),
#   datetime.date(1988, 12, 24),
#   'Senior Staff',
#   datetime.date(1987, 12, 25),
#   datetime.date(1989, 2, 27)),
#  (10772,
#   40000,
#   datetime.date(1990, 2, 22),
#   datetime.date(1991, 2, 22),
#   'Senior Engineer',
#   datetime.date(1990, 2, 22),
#   datetime.date(9999, 1, 1)),
#  (10773,
#   40000,
#   datetime.date(1997, 2, 9),
#   datetime.date(1997, 11, 29),
#   'Staff',
#   datetime.date(1997, 2, 9),
#   datetime.date(1997, 11, 29)),
#  (10788,
#   54887,
#   datetime.date(1998, 5, 29),
#   datetime.date(1999, 5, 29),
#   'Staff',
#   datetime.date(1998, 5, 29),
#   datetime.date(9999, 1, 1)),
#  (10794,
#   43485,
#   datetime.date(1994, 5, 24),
#   datetime.date(1995, 5, 24),
#   'Senior Staff',
#   datetime.date(2000, 5, 23),
#   datetime.date(9999, 1, 1)),
#  (10794,
#   43485,
#   datetime.date(1994, 5, 24),
#   datetime.date(1995, 5, 24),
#   'Staff',
#   datetime.date(1994, 5, 24),
#   datetime.date(2000, 5, 23)),
#  (10833,
#   40000,
#   datetime.date(1998, 12, 23),
#   datetime.date(1999, 12, 23),
#   'Technique Leader',
#   datetime.date(1998, 12, 23),
#   datetime.date(9999, 1, 1)),
#  (10847,
#   40000,
#   datetime.date(1986, 7, 25),
#   datetime.date(1987, 7, 25),
#   'Senior Staff',
#   datetime.date(1992, 7, 24),
#   datetime.date(9999, 1, 1)),
#  (10847,
#   40000,
#   datetime.date(1986, 7, 25),
#   datetime.date(1987, 7, 25),
#   'Staff',
#   datetime.date(1986, 7, 25),
#   datetime.date(1992, 7, 24)),
#  (10848,
#   50475,
#   datetime.date(1985, 4, 20),
#   datetime.date(1986, 4, 20),
#   'Engineer',
#   datetime.date(1985, 4, 20),
#   datetime.date(1992, 4, 20)),
#  (10848,
#   50475,
#   datetime.date(1985, 4, 20),
#   datetime.date(1986, 4, 20),
#   'Senior Engineer',
#   datetime.date(1992, 4, 20),
#   datetime.date(9999, 1, 1)),
#  (10851,
#   46644,
#   datetime.date(1994, 11, 21),
#   datetime.date(1995, 11, 21),
#   'Senior Staff',
#   datetime.date(1999, 11, 21),
#   datetime.date(9999, 1, 1)),
#  (10851,
#   46644,
#   datetime.date(1994, 11, 21),
#   datetime.date(1995, 11, 21),
#   'Staff',
#   datetime.date(1994, 11, 21),
#   datetime.date(1999, 11, 21)),
#  (10860,
#   40000,
#   datetime.date(1998, 1, 22),
#   datetime.date(1999, 1, 22),
#   'Technique Leader',
#   datetime.date(1998, 1, 22),
#   datetime.date(9999, 1, 1)),
#  (10862,
#   81455,
#   datetime.date(1985, 7, 23),
#   datetime.date(1986, 7, 23),
#   'Senior Staff',
#   datetime.date(1992, 7, 23),
#   datetime.date(9999, 1, 1)),
#  (10862,
#   81455,
#   datetime.date(1985, 7, 23),
#   datetime.date(1986, 7, 23),
#   'Staff',
#   datetime.date(1985, 7, 23),
#   datetime.date(1992, 7, 23)),
#  (10867,
#   40000,
#   datetime.date(1997, 3, 23),
#   datetime.date(1998, 3, 23),
#   'Engineer',
#   datetime.date(1997, 3, 23),
#   datetime.date(2002, 3, 22)),
#  (10873,
#   65835,
#   datetime.date(1994, 3, 23),
#   datetime.date(1995, 3, 23),
#   'Staff',
#   datetime.date(1994, 3, 23),
#   datetime.date(9999, 1, 1)),
#  (10893,
#   79803,
#   datetime.date(1989, 8, 23),
#   datetime.date(1990, 8, 23),
#   'Senior Staff',
#   datetime.date(1995, 8, 23),
#   datetime.date(9999, 1, 1)),
#  (10893,
#   79803,
#   datetime.date(1989, 8, 23),
#   datetime.date(1990, 8, 23),
#   'Staff',
#   datetime.date(1989, 8, 23),
#   datetime.date(1995, 8, 23)),
#  (10907,
#   40000,
#   datetime.date(1988, 12, 25),
#   datetime.date(1989, 12, 25),
#   'Senior Staff',
#   datetime.date(1995, 12, 26),
#   datetime.date(9999, 1, 1)),
#  (10907,
#   40000,
#   datetime.date(1988, 12, 25),
#   datetime.date(1989, 12, 25),
#   'Staff',
#   datetime.date(1988, 12, 25),
#   datetime.date(1995, 12, 26)),
#  (10908,
#   40000,
#   datetime.date(1986, 4, 5),
#   datetime.date(1987, 4, 5),
#   'Senior Staff',
#   datetime.date(1993, 4, 5),
#   datetime.date(9999, 1, 1)),
#  (10908,
#   40000,
#   datetime.date(1986, 4, 5),
#   datetime.date(1987, 4, 5),
#   'Staff',
#   datetime.date(1986, 4, 5),
#   datetime.date(1993, 4, 5)),
#  (10933,
#   40000,
#   datetime.date(1993, 8, 2),
#   datetime.date(1994, 8, 2),
#   'Senior Engineer',
#   datetime.date(1993, 8, 2),
#   datetime.date(9999, 1, 1)),
#  (10944,
#   42872,
#   datetime.date(1995, 9, 7),
#   datetime.date(1996, 9, 6),
#   'Senior Engineer',
#   datetime.date(1995, 9, 7),
#   datetime.date(9999, 1, 1)),
#  (10947,
#   43068,
#   datetime.date(1995, 11, 16),
#   datetime.date(1996, 11, 15),
#   'Senior Staff',
#   datetime.date(2001, 11, 15),
#   datetime.date(9999, 1, 1)),
#  (10947,
#   43068,
#   datetime.date(1995, 11, 16),
#   datetime.date(1996, 11, 15),
#   'Staff',
#   datetime.date(1995, 11, 16),
#   datetime.date(2001, 11, 15)),
#  (10959,
#   76685,
#   datetime.date(1994, 3, 1),
#   datetime.date(1995, 3, 1),
#   'Staff',
#   datetime.date(1994, 3, 1),
#   datetime.date(1996, 4, 12)),
#  (10973,
#   54616,
#   datetime.date(1989, 3, 5),
#   datetime.date(1990, 3, 5),
#   'Engineer',
#   datetime.date(1989, 3, 5),
#   datetime.date(1995, 3, 5)),
#  (10973,
#   54616,
#   datetime.date(1989, 3, 5),
#   datetime.date(1990, 3, 5),
#   'Senior Engineer',
#   datetime.date(1995, 3, 5),
#   datetime.date(9999, 1, 1)),
#  (10977,
#   40000,
#   datetime.date(1987, 8, 10),
#   datetime.date(1987, 10, 1),
#   'Senior Staff',
#   datetime.date(1987, 8, 10),
#   datetime.date(1987, 10, 1)),
#  (10997,
#   40000,
#   datetime.date(2000, 1, 4),
#   datetime.date(2001, 1, 3),
#   'Technique Leader',
#   datetime.date(2000, 1, 4),
#   datetime.date(9999, 1, 1)),
#  (10999,
#   55946,
#   datetime.date(1996, 3, 5),
#   datetime.date(1997, 3, 5),
#   'Technique Leader',
#   datetime.date(1996, 3, 5),
#   datetime.date(1997, 4, 19)),
#  (11015,
#   57076,
#   datetime.date(1998, 3, 14),
#   datetime.date(1999, 3, 14),
#   'Senior Staff',
#   datetime.date(1998, 3, 14),
#   datetime.date(2000, 2, 22)),
#  (11019,
#   69387,
#   datetime.date(1992, 5, 24),
#   datetime.date(1993, 5, 24),
#   'Engineer',
#   datetime.date(1992, 5, 24),
#   datetime.date(1997, 5, 24)),
#  (11019,
#   69387,
#   datetime.date(1992, 5, 24),
#   datetime.date(1993, 5, 24),
#   'Senior Engineer',
#   datetime.date(1997, 5, 24),
#   datetime.date(9999, 1, 1)),
#  (11028,
#   41111,
#   datetime.date(1986, 6, 18),
#   datetime.date(1987, 6, 18),
#   'Engineer',
#   datetime.date(1986, 6, 18),
#   datetime.date(1991, 6, 18)),
#  (11028,
#   41111,
#   datetime.date(1986, 6, 18),
#   datetime.date(1987, 6, 18),
#   'Senior Engineer',
#   datetime.date(1991, 6, 18),
#   datetime.date(1997, 9, 4)),
#  (11045,
#   40000,
#   datetime.date(1985, 8, 9),
#   datetime.date(1986, 8, 9),
#   'Engineer',
#   datetime.date(1985, 8, 9),
#   datetime.date(1994, 8, 9)),
#  (11045,
#   40000,
#   datetime.date(1985, 8, 9),
#   datetime.date(1986, 8, 9),
#   'Senior Engineer',
#   datetime.date(1994, 8, 9),
#   datetime.date(1996, 9, 29)),
#  (11058,
#   40000,
#   datetime.date(1985, 6, 7),
#   datetime.date(1986, 6, 7),
#   'Senior Staff',
#   datetime.date(1985, 6, 7),
#   datetime.date(9999, 1, 1)),
#  (11065,
#   40000,
#   datetime.date(1985, 11, 14),
#   datetime.date(1986, 11, 14),
#   'Engineer',
#   datetime.date(1985, 11, 14),
#   datetime.date(1991, 11, 14)),
#  (11065,
#   40000,
#   datetime.date(1985, 11, 14),
#   datetime.date(1986, 11, 14),
#   'Senior Engineer',
#   datetime.date(1991, 11, 14),
#   datetime.date(9999, 1, 1)),
#  (11072,
#   40000,
#   datetime.date(1994, 8, 4),
#   datetime.date(1995, 8, 4),
#   'Staff',
#   datetime.date(1994, 8, 4),
#   datetime.date(9999, 1, 1)),
#  (11077,
#   42983,
#   datetime.date(1998, 4, 30),
#   datetime.date(1998, 10, 11),
#   'Senior Staff',
#   datetime.date(1998, 4, 30),
#   datetime.date(1998, 10, 11)),
#  (11081,
#   65686,
#   datetime.date(1985, 6, 17),
#   datetime.date(1986, 6, 17),
#   'Senior Staff',
#   datetime.date(1994, 6, 17),
#   datetime.date(9999, 1, 1)),
#  (11081,
#   65686,
#   datetime.date(1985, 6, 17),
#   datetime.date(1986, 6, 17),
#   'Staff',
#   datetime.date(1985, 6, 17),
#   datetime.date(1994, 6, 17)),
#  (11085,
#   66437,
#   datetime.date(1996, 2, 10),
#   datetime.date(1997, 2, 9),
#   'Senior Engineer',
#   datetime.date(1996, 2, 10),
#   datetime.date(9999, 1, 1)),
#  (11091,
#   76253,
#   datetime.date(1999, 9, 11),
#   datetime.date(2000, 9, 10),
#   'Engineer',
#   datetime.date(1999, 9, 11),
#   datetime.date(9999, 1, 1)),
#  (11093,
#   40000,
#   datetime.date(1992, 3, 27),
#   datetime.date(1993, 3, 27),
#   'Assistant Engineer',
#   datetime.date(1992, 3, 27),
#   datetime.date(2001, 3, 27)),
#  (11093,
#   40000,
#   datetime.date(1992, 3, 27),
#   datetime.date(1993, 3, 27),
#   'Engineer',
#   datetime.date(2001, 3, 27),
#   datetime.date(9999, 1, 1)),
#  (11102,
#   68721,
#   datetime.date(1996, 10, 25),
#   datetime.date(1997, 10, 25),
#   'Staff',
#   datetime.date(1996, 10, 25),
#   datetime.date(2001, 8, 18)),
#  (11105,
#   59803,
#   datetime.date(1990, 1, 13),
#   datetime.date(1991, 1, 13),
#   'Engineer',
#   datetime.date(1990, 1, 13),
#   datetime.date(1995, 1, 13)),
#  (11105,
#   59803,
#   datetime.date(1990, 1, 13),
#   datetime.date(1991, 1, 13),
#   'Senior Engineer',
#   datetime.date(1995, 1, 13),
#   datetime.date(9999, 1, 1)),
#  (11111,
#   49777,
#   datetime.date(1994, 12, 25),
#   datetime.date(1995, 12, 25),
#   'Assistant Engineer',
#   datetime.date(1994, 12, 25),
#   datetime.date(9999, 1, 1)),
#  (11112,
#   40000,
#   datetime.date(1995, 4, 28),
#   datetime.date(1996, 4, 27),
#   'Staff',
#   datetime.date(1995, 4, 28),
#   datetime.date(9999, 1, 1)),
#  (11116,
#   40000,
#   datetime.date(1992, 10, 23),
#   datetime.date(1993, 10, 23),
#   'Engineer',
#   datetime.date(1992, 10, 23),
#   datetime.date(1999, 10, 24)),
#  (11116,
#   40000,
#   datetime.date(1992, 10, 23),
#   datetime.date(1993, 10, 23),
#   'Senior Engineer',
#   datetime.date(1999, 10, 24),
#   datetime.date(9999, 1, 1)),
#  (11125,
#   45360,
#   datetime.date(1995, 8, 10),
#   datetime.date(1996, 8, 9),
#   'Engineer',
#   datetime.date(1995, 8, 10),
#   datetime.date(9999, 1, 1)),
#  (11149,
#   99680,
#   datetime.date(1987, 8, 26),
#   datetime.date(1988, 8, 25),
#   'Senior Staff',
#   datetime.date(1995, 8, 26),
#   datetime.date(9999, 1, 1)),
#  (11149,
#   99680,
#   datetime.date(1987, 8, 26),
#   datetime.date(1988, 8, 25),
#   'Staff',
#   datetime.date(1987, 8, 26),
#   datetime.date(1995, 8, 26)),
#  (11177,
#   40000,
#   datetime.date(1999, 9, 11),
#   datetime.date(2000, 9, 10),
#   'Senior Engineer',
#   datetime.date(1999, 9, 11),
#   datetime.date(9999, 1, 1)),
#  (11199,
#   40000,
#   datetime.date(1989, 5, 2),
#   datetime.date(1990, 5, 2),
#   'Technique Leader',
#   datetime.date(1989, 5, 2),
#   datetime.date(9999, 1, 1)),
#  (11203,
#   68049,
#   datetime.date(1988, 1, 6),
#   datetime.date(1989, 1, 5),
#   'Senior Staff',
#   datetime.date(1996, 1, 6),
#   datetime.date(1996, 6, 15)),
#  (11203,
#   68049,
#   datetime.date(1988, 1, 6),
#   datetime.date(1989, 1, 5),
#   'Staff',
#   datetime.date(1988, 1, 6),
#   datetime.date(1996, 1, 6)),
#  (11215,
#   70468,
#   datetime.date(1992, 10, 17),
#   datetime.date(1993, 10, 17),
#   'Technique Leader',
#   datetime.date(1992, 10, 17),
#   datetime.date(9999, 1, 1)),
#  (11232,
#   43863,
#   datetime.date(1994, 8, 2),
#   datetime.date(1995, 8, 2),
#   'Senior Staff',
#   datetime.date(2000, 8, 1),
#   datetime.date(9999, 1, 1)),
#  (11232,
#   43863,
#   datetime.date(1994, 8, 2),
#   datetime.date(1995, 8, 2),
#   'Staff',
#   datetime.date(1994, 8, 2),
#   datetime.date(2000, 8, 1)),
#  (11247,
#   40000,
#   datetime.date(1993, 10, 11),
#   datetime.date(1994, 10, 11),
#   'Senior Staff',
#   datetime.date(2001, 10, 11),
#   datetime.date(9999, 1, 1)),
#  (11247,
#   40000,
#   datetime.date(1993, 10, 11),
#   datetime.date(1994, 10, 11),
#   'Staff',
#   datetime.date(1993, 10, 11),
#   datetime.date(2001, 10, 11)),
#  (11248,
#   67711,
#   datetime.date(1997, 2, 3),
#   datetime.date(1998, 2, 3),
#   'Staff',
#   datetime.date(1997, 2, 3),
#   datetime.date(1999, 7, 19)),
#  (11253,
#   40000,
#   datetime.date(1992, 5, 22),
#   datetime.date(1993, 5, 22),
#   'Engineer',
#   datetime.date(1992, 5, 22),
#   datetime.date(2000, 5, 22)),
#  (11253,
#   40000,
#   datetime.date(1992, 5, 22),
#   datetime.date(1993, 5, 22),
#   'Senior Engineer',
#   datetime.date(2000, 5, 22),
#   datetime.date(9999, 1, 1)),
#  (11277,
#   52519,
#   datetime.date(1995, 7, 19),
#   datetime.date(1996, 7, 18),
#   'Senior Staff',
#   datetime.date(1995, 7, 19),
#   datetime.date(9999, 1, 1)),
#  (11287,
#   64454,
#   datetime.date(1987, 8, 12),
#   datetime.date(1988, 8, 11),
#   'Senior Staff',
#   datetime.date(1995, 8, 12),
#   datetime.date(9999, 1, 1)),
#  (11287,
#   64454,
#   datetime.date(1987, 8, 12),
#   datetime.date(1988, 8, 11),
#   'Staff',
#   datetime.date(1987, 8, 12),
#   datetime.date(1995, 8, 12)),
#  (11293,
#   63418,
#   datetime.date(1992, 8, 8),
#   datetime.date(1993, 8, 8),
#   'Senior Engineer',
#   datetime.date(1992, 8, 8),
#   datetime.date(1998, 3, 13)),
#  (11294,
#   43768,
#   datetime.date(1989, 6, 13),
#   datetime.date(1990, 6, 13),
#   'Assistant Engineer',
#   datetime.date(1989, 6, 13),
#   datetime.date(1994, 6, 13)),
#  (11294,
#   43768,
#   datetime.date(1989, 6, 13),
#   datetime.date(1990, 6, 13),
#   'Engineer',
#   datetime.date(1994, 6, 13),
#   datetime.date(1999, 6, 13)),
#  (11294,
#   43768,
#   datetime.date(1989, 6, 13),
#   datetime.date(1990, 6, 13),
#   'Senior Engineer',
#   datetime.date(1999, 6, 13),
#   datetime.date(9999, 1, 1)),
#  (11328,
#   61119,
#   datetime.date(1986, 8, 8),
#   datetime.date(1987, 8, 8),
#   'Senior Staff',
#   datetime.date(1994, 8, 8),
#   datetime.date(9999, 1, 1)),
#  (11328,
#   61119,
#   datetime.date(1986, 8, 8),
#   datetime.date(1987, 8, 8),
#   'Staff',
#   datetime.date(1986, 8, 8),
#   datetime.date(1994, 8, 8)),
#  (11335,
#   40000,
#   datetime.date(1991, 10, 8),
#   datetime.date(1992, 10, 7),
#   'Senior Staff',
#   datetime.date(2000, 10, 7),
#   datetime.date(9999, 1, 1)),
#  (11335,
#   40000,
#   datetime.date(1991, 10, 8),
#   datetime.date(1992, 10, 7),
#   'Staff',
#   datetime.date(1991, 10, 8),
#   datetime.date(2000, 10, 7)),
#  (11337,
#   42659,
#   datetime.date(1998, 2, 21),
#   datetime.date(1999, 2, 21),
#   'Staff',
#   datetime.date(1998, 2, 21),
#   datetime.date(2002, 5, 11)),
#  (11343,
#   43306,
#   datetime.date(1989, 2, 27),
#   datetime.date(1990, 2, 27),
#   'Engineer',
#   datetime.date(1989, 2, 27),
#   datetime.date(1995, 2, 27)),
#  (11343,
#   43306,
#   datetime.date(1989, 2, 27),
#   datetime.date(1990, 2, 27),
#   'Senior Engineer',
#   datetime.date(1995, 2, 27),
#   datetime.date(9999, 1, 1)),
#  (11345,
#   61656,
#   datetime.date(1998, 11, 25),
#   datetime.date(1999, 11, 25),
#   'Engineer',
#   datetime.date(1998, 11, 25),
#   datetime.date(9999, 1, 1)),
#  (11349,
#   46356,
#   datetime.date(1992, 6, 27),
#   datetime.date(1993, 6, 27),
#   'Assistant Engineer',
#   datetime.date(1992, 6, 27),
#   datetime.date(1999, 6, 28)),
#  (11349,
#   46356,
#   datetime.date(1992, 6, 27),
#   datetime.date(1993, 6, 27),
#   'Engineer',
#   datetime.date(1999, 6, 28),
#   datetime.date(9999, 1, 1)),
#  (11365,
#   56463,
#   datetime.date(1997, 12, 18),
#   datetime.date(1998, 12, 18),
#   'Engineer',
#   datetime.date(1997, 12, 18),
#   datetime.date(9999, 1, 1)),
#  (11371,
#   46423,
#   datetime.date(1988, 12, 25),
#   datetime.date(1989, 12, 25),
#   'Assistant Engineer',
#   datetime.date(1988, 12, 25),
#   datetime.date(1993, 12, 25)),
#  (11371,
#   46423,
#   datetime.date(1988, 12, 25),
#   datetime.date(1989, 12, 25),
#   'Engineer',
#   datetime.date(1993, 12, 25),
#   datetime.date(1998, 12, 25)),
#  (11371,
#   46423,
#   datetime.date(1988, 12, 25),
#   datetime.date(1989, 12, 25),
#   'Senior Engineer',
#   datetime.date(1998, 12, 25),
#   datetime.date(9999, 1, 1)),
#  (11374,
#   51611,
#   datetime.date(1997, 7, 19),
#   datetime.date(1998, 7, 19),
#   'Engineer',
#   datetime.date(1997, 7, 19),
#   datetime.date(9999, 1, 1)),
#  (11378,
#   40000,
#   datetime.date(1986, 1, 3),
#   datetime.date(1987, 1, 3),
#   'Engineer',
#   datetime.date(1986, 1, 3),
#   datetime.date(1991, 1, 3)),
#  (11378,
#   40000,
#   datetime.date(1986, 1, 3),
#   datetime.date(1987, 1, 3),
#   'Senior Engineer',
#   datetime.date(1991, 1, 3),
#   datetime.date(9999, 1, 1)),
#  (11384,
#   40000,
#   datetime.date(1994, 6, 3),
#   datetime.date(1995, 6, 3),
#   'Senior Staff',
#   datetime.date(2001, 6, 3),
#   datetime.date(9999, 1, 1)),
#  (11384,
#   40000,
#   datetime.date(1994, 6, 3),
#   datetime.date(1995, 6, 3),
#   'Staff',
#   datetime.date(1994, 6, 3),
#   datetime.date(2001, 6, 3)),
#  (11389,
#   86011,
#   datetime.date(1992, 2, 20),
#   datetime.date(1993, 2, 19),
#   'Senior Staff',
#   datetime.date(2000, 2, 20),
#   datetime.date(9999, 1, 1)),
#  (11389,
#   86011,
#   datetime.date(1992, 2, 20),
#   datetime.date(1993, 2, 19),
#   'Staff',
#   datetime.date(1992, 2, 20),
#   datetime.date(2000, 2, 20)),
#  (11393,
#   40000,
#   datetime.date(1985, 4, 30),
#   datetime.date(1986, 4, 30),
#   'Engineer',
#   datetime.date(1985, 4, 30),
#   datetime.date(1992, 4, 30)),
#  (11393,
#   40000,
#   datetime.date(1985, 4, 30),
#   datetime.date(1986, 4, 30),
#   'Senior Engineer',
#   datetime.date(1992, 4, 30),
#   datetime.date(9999, 1, 1)),
#  (11406,
#   71834,
#   datetime.date(1989, 3, 13),
#   datetime.date(1990, 3, 13),
#   'Senior Staff',
#   datetime.date(1996, 3, 13),
#   datetime.date(9999, 1, 1)),
#  (11406,
#   71834,
#   datetime.date(1989, 3, 13),
#   datetime.date(1990, 3, 13),
#   'Staff',
#   datetime.date(1989, 3, 13),
#   datetime.date(1996, 3, 13)),
#  (11414,
#   76725,
#   datetime.date(1989, 1, 2),
#   datetime.date(1990, 1, 2),
#   'Senior Staff',
#   datetime.date(1996, 1, 3),
#   datetime.date(1997, 10, 6)),
#  (11414,
#   76725,
#   datetime.date(1989, 1, 2),
#   datetime.date(1990, 1, 2),
#   'Staff',
#   datetime.date(1989, 1, 2),
#   datetime.date(1996, 1, 3)),
#  (11415,
#   40000,
#   datetime.date(1996, 12, 7),
#   datetime.date(1997, 12, 7),
#   'Engineer',
#   datetime.date(1996, 12, 7),
#   datetime.date(9999, 1, 1)),
#  (11434,
#   54798,
#   datetime.date(1992, 10, 18),
#   datetime.date(1993, 10, 18),
#   'Senior Staff',
#   datetime.date(1999, 10, 19),
#   datetime.date(9999, 1, 1)),
#  (11434,
#   54798,
#   datetime.date(1992, 10, 18),
#   datetime.date(1993, 10, 18),
#   'Staff',
#   datetime.date(1992, 10, 18),
#   datetime.date(1999, 10, 19)),
#  (11439,
#   69470,
#   datetime.date(1997, 5, 23),
#   datetime.date(1998, 5, 23),
#   'Engineer',
#   datetime.date(1997, 5, 23),
#   datetime.date(9999, 1, 1)),
#  (11448,
#   40000,
#   datetime.date(1995, 8, 26),
#   datetime.date(1996, 8, 25),
#   'Technique Leader',
#   datetime.date(1995, 8, 26),
#   datetime.date(9999, 1, 1)),
#  (11455,
#   46590,
#   datetime.date(1994, 8, 14),
#   datetime.date(1995, 8, 14),
#   'Engineer',
#   datetime.date(1994, 8, 14),
#   datetime.date(1998, 9, 13)),
#  (11468,
#   85983,
#   datetime.date(1996, 3, 19),
#   datetime.date(1997, 3, 19),
#   'Staff',
#   datetime.date(1996, 3, 19),
#   datetime.date(1997, 4, 7)),
#  (11478,
#   93693,
#   datetime.date(1999, 9, 10),
#   datetime.date(2000, 9, 9),
#   'Senior Staff',
#   datetime.date(1999, 9, 10),
#   datetime.date(9999, 1, 1)),
#  (11479,
#   78157,
#   datetime.date(1999, 2, 10),
#   datetime.date(2000, 2, 10),
#   'Staff',
#   datetime.date(1999, 2, 10),
#   datetime.date(9999, 1, 1)),
#  (11485,
#   45743,
#   datetime.date(1993, 10, 12),
#   datetime.date(1994, 10, 12),
#   'Engineer',
#   datetime.date(1993, 10, 12),
#   datetime.date(2000, 10, 12)),
#  (11485,
#   45743,
#   datetime.date(1993, 10, 12),
#   datetime.date(1994, 10, 12),
#   'Senior Engineer',
#   datetime.date(2000, 10, 12),
#   datetime.date(9999, 1, 1)),
#  (11490,
#   40000,
#   datetime.date(1997, 10, 24),
#   datetime.date(1998, 10, 24),
#   'Staff',
#   datetime.date(1997, 10, 24),
#   datetime.date(9999, 1, 1)),
#  (11494,
#   46637,
#   datetime.date(1991, 2, 14),
#   datetime.date(1992, 2, 14),
#   'Assistant Engineer',
#   datetime.date(1991, 2, 14),
#   datetime.date(1999, 2, 14)),
#  (11494,
#   46637,
#   datetime.date(1991, 2, 14),
#   datetime.date(1992, 2, 14),
#   'Engineer',
#   datetime.date(1999, 2, 14),
#   datetime.date(9999, 1, 1)),
#  (11495,
#   40220,
#   datetime.date(1989, 9, 13),
#   datetime.date(1990, 9, 13),
#   'Senior Staff',
#   datetime.date(1994, 9, 13),
#   datetime.date(9999, 1, 1)),
#  (11495,
#   40220,
#   datetime.date(1989, 9, 13),
#   datetime.date(1990, 9, 13),
#   'Staff',
#   datetime.date(1989, 9, 13),
#   datetime.date(1994, 9, 13)),
#  (11496,
#   40000,
#   datetime.date(1992, 7, 9),
#   datetime.date(1993, 7, 9),
#   'Assistant Engineer',
#   datetime.date(1992, 7, 9),
#   datetime.date(1999, 7, 10)),
#  (11496,
#   40000,
#   datetime.date(1992, 7, 9),
#   datetime.date(1993, 7, 9),
#   'Engineer',
#   datetime.date(1999, 7, 10),
#   datetime.date(9999, 1, 1)),
#  (11510,
#   40000,
#   datetime.date(1998, 12, 29),
#   datetime.date(1999, 12, 29),
#   'Staff',
#   datetime.date(1998, 12, 29),
#   datetime.date(2001, 4, 1)),
#  (11515,
#   70182,
#   datetime.date(1998, 9, 21),
#   datetime.date(1999, 9, 21),
#   'Staff',
#   datetime.date(1998, 9, 21),
#   datetime.date(9999, 1, 1)),
#  (11544,
#   41062,
#   datetime.date(1993, 12, 20),
#   datetime.date(1994, 12, 20),
#   'Senior Staff',
#   datetime.date(1993, 12, 20),
#   datetime.date(9999, 1, 1)),
#  (11557,
#   57561,
#   datetime.date(1998, 12, 17),
#   datetime.date(1999, 12, 17),
#   'Staff',
#   datetime.date(1998, 12, 17),
#   datetime.date(2001, 9, 28)),
#  (11572,
#   40000,
#   datetime.date(1985, 8, 23),
#   datetime.date(1986, 8, 23),
#   'Engineer',
#   datetime.date(1985, 8, 23),
#   datetime.date(1991, 8, 23)),
#  (11572,
#   40000,
#   datetime.date(1985, 8, 23),
#   datetime.date(1986, 8, 23),
#   'Senior Engineer',
#   datetime.date(1991, 8, 23),
#   datetime.date(9999, 1, 1)),
#  (11588,
#   40000,
#   datetime.date(1994, 12, 24),
#   datetime.date(1995, 6, 12),
#   'Senior Staff',
#   datetime.date(1994, 12, 24),
#   datetime.date(1995, 6, 12)),
#  (11599,
#   72403,
#   datetime.date(1995, 10, 19),
#   datetime.date(1996, 10, 18),
#   'Engineer',
#   datetime.date(1995, 10, 19),
#   datetime.date(9999, 1, 1)),
#  (11605,
#   40000,
#   datetime.date(1994, 10, 8),
#   datetime.date(1995, 10, 8),
#   'Engineer',
#   datetime.date(1994, 10, 8),
#   datetime.date(2000, 5, 24)),
#  (11616,
#   41900,
#   datetime.date(1993, 12, 30),
#   datetime.date(1994, 12, 30),
#   'Assistant Engineer',
#   datetime.date(1993, 12, 30),
#   datetime.date(1998, 12, 30)),
#  (11616,
#   41900,
#   datetime.date(1993, 12, 30),
#   datetime.date(1994, 12, 30),
#   'Engineer',
#   datetime.date(1998, 12, 30),
#   datetime.date(9999, 1, 1)),
#  (11621,
#   60596,
#   datetime.date(1986, 11, 17),
#   datetime.date(1987, 11, 17),
#   'Senior Staff',
#   datetime.date(1991, 11, 17),
#   datetime.date(9999, 1, 1)),
#  (11621,
#   60596,
#   datetime.date(1986, 11, 17),
#   datetime.date(1987, 11, 17),
#   'Staff',
#   datetime.date(1986, 11, 17),
#   datetime.date(1991, 11, 17)),
#  (11633,
#   40000,
#   datetime.date(1994, 9, 28),
#   datetime.date(1995, 9, 28),
#   'Engineer',
#   datetime.date(1994, 9, 28),
#   datetime.date(9999, 1, 1)),
#  (11634,
#   42068,
#   datetime.date(2000, 1, 1),
#   datetime.date(2000, 12, 31),
#   'Engineer',
#   datetime.date(2000, 1, 1),
#   datetime.date(9999, 1, 1)),
#  (11682,
#   48241,
#   datetime.date(1986, 11, 27),
#   datetime.date(1987, 11, 27),
#   'Senior Staff',
#   datetime.date(1995, 11, 27),
#   datetime.date(9999, 1, 1)),
#  (11682,
#   48241,
#   datetime.date(1986, 11, 27),
#   datetime.date(1987, 11, 27),
#   'Staff',
#   datetime.date(1986, 11, 27),
#   datetime.date(1995, 11, 27)),
#  (11693,
#   70403,
#   datetime.date(1991, 8, 24),
#   datetime.date(1992, 8, 23),
#   'Senior Engineer',
#   datetime.date(1991, 8, 24),
#   datetime.date(9999, 1, 1)),
#  (11697,
#   44268,
#   datetime.date(1999, 12, 10),
#   datetime.date(2000, 12, 9),
#   'Technique Leader',
#   datetime.date(1999, 12, 10),
#   datetime.date(9999, 1, 1)),
#  (11709,
#   43381,
#   datetime.date(1985, 11, 9),
#   datetime.date(1986, 11, 9),
#   'Engineer',
#   datetime.date(1985, 11, 9),
#   datetime.date(1991, 11, 9)),
#  (11709,
#   43381,
#   datetime.date(1985, 11, 9),
#   datetime.date(1986, 11, 9),
#   'Senior Engineer',
#   datetime.date(1991, 11, 9),
#   datetime.date(9999, 1, 1)),
#  (11722,
#   40000,
#   datetime.date(1997, 12, 18),
#   datetime.date(1998, 12, 18),
#   'Engineer',
#   datetime.date(1997, 12, 18),
#   datetime.date(9999, 1, 1)),
#  (11734,
#   49728,
#   datetime.date(1998, 8, 9),
#   datetime.date(1999, 8, 9),
#   'Staff',
#   datetime.date(1998, 8, 9),
#   datetime.date(9999, 1, 1)),
#  (11752,
#   60876,
#   datetime.date(1992, 11, 10),
#   datetime.date(1993, 11, 10),
#   'Senior Staff',
#   datetime.date(1998, 11, 10),
#   datetime.date(9999, 1, 1)),
#  (11752,
#   60876,
#   datetime.date(1992, 11, 10),
#   datetime.date(1993, 11, 10),
#   'Staff',
#   datetime.date(1992, 11, 10),
#   datetime.date(1998, 11, 10)),
#  (11761,
#   52986,
#   datetime.date(1991, 6, 12),
#   datetime.date(1992, 6, 11),
#   'Senior Staff',
#   datetime.date(1998, 6, 12),
#   datetime.date(9999, 1, 1)),
#  (11761,
#   52986,
#   datetime.date(1991, 6, 12),
#   datetime.date(1992, 6, 11),
#   'Staff',
#   datetime.date(1991, 6, 12),
#   datetime.date(1998, 6, 12)),
#  (11770,
#   40000,
#   datetime.date(1992, 11, 29),
#   datetime.date(1993, 11, 29),
#   'Engineer',
#   datetime.date(1992, 11, 29),
#   datetime.date(2000, 11, 29)),
#  (11770,
#   40000,
#   datetime.date(1992, 11, 29),
#   datetime.date(1993, 11, 29),
#   'Senior Engineer',
#   datetime.date(2000, 11, 29),
#   datetime.date(9999, 1, 1)),
#  (11773,
#   40000,
#   datetime.date(1990, 5, 29),
#   datetime.date(1991, 5, 29),
#   'Senior Staff',
#   datetime.date(1997, 5, 29),
#   datetime.date(9999, 1, 1)),
#  (11773,
#   40000,
#   datetime.date(1990, 5, 29),
#   datetime.date(1991, 5, 29),
#   'Staff',
#   datetime.date(1990, 5, 29),
#   datetime.date(1997, 5, 29)),
#  (11788,
#   59292,
#   datetime.date(1986, 10, 3),
#   datetime.date(1987, 10, 3),
#   'Technique Leader',
#   datetime.date(1986, 10, 3),
#   datetime.date(9999, 1, 1)),
#  (11790,
#   41777,
#   datetime.date(1988, 3, 9),
#   datetime.date(1989, 3, 9),
#   'Senior Engineer',
#   datetime.date(1988, 3, 9),
#   datetime.date(9999, 1, 1)),
#  (11799,
#   58726,
#   datetime.date(1996, 3, 6),
#   datetime.date(1997, 3, 6),
#   'Assistant Engineer',
#   datetime.date(1996, 3, 6),
#   datetime.date(9999, 1, 1)),
#  (11801,
#   67265,
#   datetime.date(1992, 6, 12),
#   datetime.date(1993, 6, 12),
#   'Senior Staff',
#   datetime.date(1997, 6, 12),
#   datetime.date(9999, 1, 1)),
#  (11801,
#   67265,
#   datetime.date(1992, 6, 12),
#   datetime.date(1993, 6, 12),
#   'Staff',
#   datetime.date(1992, 6, 12),
#   datetime.date(1997, 6, 12)),
#  (11812,
#   47297,
#   datetime.date(1987, 9, 30),
#   datetime.date(1988, 9, 29),
#   'Senior Staff',
#   datetime.date(1987, 9, 30),
#   datetime.date(9999, 1, 1)),
#  (11816,
#   53163,
#   datetime.date(1991, 8, 5),
#   datetime.date(1992, 8, 4),
#   'Senior Staff',
#   datetime.date(1997, 8, 4),
#   datetime.date(9999, 1, 1)),
#  (11816,
#   53163,
#   datetime.date(1991, 8, 5),
#   datetime.date(1992, 8, 4),
#   'Staff',
#   datetime.date(1991, 8, 5),
#   datetime.date(1997, 8, 4)),
#  (11821,
#   50404,
#   datetime.date(1995, 12, 13),
#   datetime.date(1996, 12, 12),
#   'Senior Engineer',
#   datetime.date(1995, 12, 13),
#   datetime.date(2001, 10, 26)),
#  (11827,
#   43015,
#   datetime.date(1995, 7, 13),
#   datetime.date(1996, 7, 12),
#   'Staff',
#   datetime.date(1995, 7, 13),
#   datetime.date(2000, 7, 18)),
#  (11839,
#   73024,
#   datetime.date(1990, 12, 14),
#   datetime.date(1991, 12, 14),
#   'Engineer',
#   datetime.date(1990, 12, 14),
#   datetime.date(1996, 12, 13)),
#  (11839,
#   73024,
#   datetime.date(1990, 12, 14),
#   datetime.date(1991, 12, 14),
#   'Senior Engineer',
#   datetime.date(1996, 12, 13),
#   datetime.date(9999, 1, 1)),
#  (11863,
#   54220,
#   datetime.date(1988, 12, 16),
#   datetime.date(1989, 12, 16),
#   'Engineer',
#   datetime.date(1988, 12, 16),
# ...
#   'Senior Staff',
#   datetime.date(1991, 1, 17),
#   datetime.date(9999, 1, 1)),
#  (15063,
#   42399,
#   datetime.date(1996, 1, 25),
#   datetime.date(1997, 1, 24),
#   'Senior Engineer',
#   datetime.date(1996, 1, 25),
#   datetime.date(9999, 1, 1)),
#  (15076,
#   54929,
#   datetime.date(1989, 6, 28),
#   datetime.date(1990, 6, 28),
#   'Senior Staff',
#   datetime.date(1996, 6, 28),
#   datetime.date(9999, 1, 1)),
#  (15076,
#   54929,
#   datetime.date(1989, 6, 28),
#   datetime.date(1990, 6, 28),
#   'Staff',
#   datetime.date(1989, 6, 28),
#   datetime.date(1996, 6, 28)),
#  (15089,
#   48594,
#   datetime.date(1987, 5, 14),
#   datetime.date(1988, 5, 13),
#   'Engineer',
#   datetime.date(1987, 5, 14),
#   datetime.date(1995, 5, 14)),
#  (15089,
#   48594,
#   datetime.date(1987, 5, 14),
#   datetime.date(1988, 5, 13),
#   'Senior Engineer',
#   datetime.date(1995, 5, 14),
#   datetime.date(9999, 1, 1)),
#  (15090,
#   61094,
#   datetime.date(1986, 8, 31),
#   datetime.date(1987, 8, 31),
#   'Engineer',
#   datetime.date(1986, 8, 31),
#   datetime.date(1991, 8, 31)),
#  (15090,
#   61094,
#   datetime.date(1986, 8, 31),
#   datetime.date(1987, 8, 31),
#   'Senior Engineer',
#   datetime.date(1991, 8, 31),
#   datetime.date(9999, 1, 1)),
#  (15109,
#   68320,
#   datetime.date(1988, 9, 3),
#   datetime.date(1989, 9, 3),
#   'Engineer',
#   datetime.date(1988, 9, 3),
#   datetime.date(1997, 9, 3)),
#  (15109,
#   68320,
#   datetime.date(1988, 9, 3),
#   datetime.date(1989, 9, 3),
#   'Senior Engineer',
#   datetime.date(1997, 9, 3),
#   datetime.date(9999, 1, 1)),
#  (15113,
#   62081,
#   datetime.date(1988, 9, 23),
#   datetime.date(1989, 9, 23),
#   'Staff',
#   datetime.date(1988, 9, 23),
#   datetime.date(1993, 1, 26)),
#  (15114,
#   40000,
#   datetime.date(1998, 3, 9),
#   datetime.date(1999, 3, 9),
#   'Engineer',
#   datetime.date(1998, 3, 9),
#   datetime.date(9999, 1, 1)),
#  (15127,
#   84359,
#   datetime.date(1991, 1, 16),
#   datetime.date(1992, 1, 16),
#   'Senior Staff',
#   datetime.date(1991, 1, 16),
#   datetime.date(1999, 2, 21)),
#  (15138,
#   60586,
#   datetime.date(1987, 7, 7),
#   datetime.date(1988, 7, 6),
#   'Engineer',
#   datetime.date(1987, 7, 7),
#   datetime.date(1993, 7, 6)),
#  (15138,
#   60586,
#   datetime.date(1987, 7, 7),
#   datetime.date(1988, 7, 6),
#   'Senior Engineer',
#   datetime.date(1993, 7, 6),
#   datetime.date(9999, 1, 1)),
#  (15147,
#   52179,
#   datetime.date(1985, 7, 31),
#   datetime.date(1986, 7, 31),
#   'Engineer',
#   datetime.date(1985, 7, 31),
#   datetime.date(1992, 7, 31)),
#  (15147,
#   52179,
#   datetime.date(1985, 7, 31),
#   datetime.date(1986, 7, 31),
#   'Senior Engineer',
#   datetime.date(1992, 7, 31),
#   datetime.date(9999, 1, 1)),
#  (15153,
#   40000,
#   datetime.date(1996, 2, 10),
#   datetime.date(1997, 2, 9),
#   'Technique Leader',
#   datetime.date(1996, 2, 10),
#   datetime.date(9999, 1, 1)),
#  (15156,
#   61128,
#   datetime.date(1995, 3, 14),
#   datetime.date(1996, 3, 13),
#   'Engineer',
#   datetime.date(1995, 3, 14),
#   datetime.date(2000, 3, 13)),
#  (15156,
#   61128,
#   datetime.date(1995, 3, 14),
#   datetime.date(1996, 3, 13),
#   'Senior Engineer',
#   datetime.date(2000, 3, 13),
#   datetime.date(9999, 1, 1)),
#  (15169,
#   64912,
#   datetime.date(1999, 9, 10),
#   datetime.date(2000, 9, 9),
#   'Technique Leader',
#   datetime.date(1999, 9, 10),
#   datetime.date(9999, 1, 1)),
#  (15177,
#   40000,
#   datetime.date(1998, 2, 21),
#   datetime.date(1999, 2, 21),
#   'Staff',
#   datetime.date(1998, 2, 21),
#   datetime.date(2000, 8, 19)),
#  (15182,
#   40000,
#   datetime.date(1996, 8, 13),
#   datetime.date(1997, 8, 13),
#   'Staff',
#   datetime.date(1996, 8, 13),
#   datetime.date(9999, 1, 1)),
#  (15185,
#   48898,
#   datetime.date(1995, 4, 8),
#   datetime.date(1996, 4, 6),
#   'Engineer',
#   datetime.date(1995, 4, 8),
#   datetime.date(2001, 4, 7)),
#  (15185,
#   48898,
#   datetime.date(1995, 4, 8),
#   datetime.date(1996, 4, 6),
#   'Senior Engineer',
#   datetime.date(2001, 4, 7),
#   datetime.date(9999, 1, 1)),
#  (15186,
#   75764,
#   datetime.date(1989, 12, 6),
#   datetime.date(1990, 12, 6),
#   'Senior Staff',
#   datetime.date(1996, 12, 6),
#   datetime.date(9999, 1, 1)),
#  (15186,
#   75764,
#   datetime.date(1989, 12, 6),
#   datetime.date(1990, 12, 6),
#   'Staff',
#   datetime.date(1989, 12, 6),
#   datetime.date(1996, 12, 6)),
#  (15187,
#   43249,
#   datetime.date(1997, 6, 13),
#   datetime.date(1998, 6, 13),
#   'Engineer',
#   datetime.date(1997, 6, 13),
#   datetime.date(2000, 1, 21)),
#  (15191,
#   40000,
#   datetime.date(1989, 1, 8),
#   datetime.date(1990, 1, 8),
#   'Technique Leader',
#   datetime.date(1989, 1, 8),
#   datetime.date(9999, 1, 1)),
#  (15192,
#   40000,
#   datetime.date(1989, 4, 24),
#   datetime.date(1990, 4, 24),
#   'Engineer',
#   datetime.date(1989, 4, 24),
#   datetime.date(1998, 4, 24)),
#  (15192,
#   40000,
#   datetime.date(1989, 4, 24),
#   datetime.date(1990, 4, 24),
#   'Senior Engineer',
#   datetime.date(1998, 4, 24),
#   datetime.date(9999, 1, 1)),
#  (15197,
#   40000,
#   datetime.date(1994, 10, 7),
#   datetime.date(1995, 10, 7),
#   'Engineer',
#   datetime.date(1994, 10, 7),
#   datetime.date(9999, 1, 1)),
#  (15204,
#   40000,
#   datetime.date(1997, 1, 5),
#   datetime.date(1998, 1, 5),
#   'Engineer',
#   datetime.date(1997, 1, 5),
#   datetime.date(9999, 1, 1)),
#  (15207,
#   44839,
#   datetime.date(1992, 3, 13),
#   datetime.date(1993, 3, 13),
#   'Senior Engineer',
#   datetime.date(1992, 3, 13),
#   datetime.date(9999, 1, 1)),
#  (15224,
#   54629,
#   datetime.date(1998, 8, 31),
#   datetime.date(1999, 8, 31),
#   'Engineer',
#   datetime.date(1998, 8, 31),
#   datetime.date(9999, 1, 1)),
#  (15227,
#   72041,
#   datetime.date(1993, 3, 15),
#   datetime.date(1994, 3, 15),
#   'Senior Staff',
#   datetime.date(1998, 3, 15),
#   datetime.date(9999, 1, 1)),
#  (15227,
#   72041,
#   datetime.date(1993, 3, 15),
#   datetime.date(1994, 3, 15),
#   'Staff',
#   datetime.date(1993, 3, 15),
#   datetime.date(1998, 3, 15)),
#  (15237,
#   40000,
#   datetime.date(1987, 8, 17),
#   datetime.date(1988, 8, 16),
#   'Engineer',
#   datetime.date(1987, 8, 17),
#   datetime.date(1995, 8, 17)),
#  (15237,
#   40000,
#   datetime.date(1987, 8, 17),
#   datetime.date(1988, 8, 16),
#   'Senior Engineer',
#   datetime.date(1995, 8, 17),
#   datetime.date(9999, 1, 1)),
#  (15239,
#   40000,
#   datetime.date(1995, 9, 3),
#   datetime.date(1996, 9, 2),
#   'Engineer',
#   datetime.date(1995, 9, 3),
#   datetime.date(9999, 1, 1)),
#  (15250,
#   60152,
#   datetime.date(1992, 10, 28),
#   datetime.date(1993, 10, 28),
#   'Engineer',
#   datetime.date(1992, 10, 28),
#   datetime.date(2000, 10, 28)),
#  (15250,
#   60152,
#   datetime.date(1992, 10, 28),
#   datetime.date(1993, 10, 28),
#   'Senior Engineer',
#   datetime.date(2000, 10, 28),
#   datetime.date(9999, 1, 1)),
#  (15252,
#   51572,
#   datetime.date(1993, 1, 12),
#   datetime.date(1994, 1, 12),
#   'Technique Leader',
#   datetime.date(1993, 1, 12),
#   datetime.date(1996, 10, 14)),
#  (15274,
#   40000,
#   datetime.date(1993, 1, 30),
#   datetime.date(1994, 1, 30),
#   'Engineer',
#   datetime.date(1993, 1, 30),
#   datetime.date(1996, 5, 5)),
#  (15294,
#   40000,
#   datetime.date(1999, 6, 7),
#   datetime.date(2000, 6, 6),
#   'Engineer',
#   datetime.date(1999, 6, 7),
#   datetime.date(9999, 1, 1)),
#  (15298,
#   43452,
#   datetime.date(1986, 8, 16),
#   datetime.date(1987, 8, 16),
#   'Engineer',
#   datetime.date(1986, 8, 16),
#   datetime.date(1992, 8, 15)),
#  (15298,
#   43452,
#   datetime.date(1986, 8, 16),
#   datetime.date(1987, 8, 16),
#   'Senior Engineer',
#   datetime.date(1992, 8, 15),
#   datetime.date(9999, 1, 1)),
#  (15306,
#   51139,
#   datetime.date(1999, 3, 8),
#   datetime.date(2000, 3, 7),
#   'Staff',
#   datetime.date(1999, 3, 8),
#   datetime.date(9999, 1, 1)),
#  (15314,
#   47317,
#   datetime.date(1989, 5, 31),
#   datetime.date(1990, 5, 31),
#   'Engineer',
#   datetime.date(1989, 5, 31),
#   datetime.date(1996, 5, 31)),
#  (15314,
#   47317,
#   datetime.date(1989, 5, 31),
#   datetime.date(1990, 5, 31),
#   'Senior Engineer',
#   datetime.date(1996, 5, 31),
#   datetime.date(9999, 1, 1)),
#  (15315,
#   48786,
#   datetime.date(1996, 1, 14),
#   datetime.date(1997, 1, 13),
#   'Staff',
#   datetime.date(1996, 1, 14),
#   datetime.date(9999, 1, 1)),
#  (15316,
#   56080,
#   datetime.date(1992, 12, 11),
#   datetime.date(1993, 12, 11),
#   'Senior Staff',
#   datetime.date(1999, 12, 12),
#   datetime.date(9999, 1, 1)),
#  (15316,
#   56080,
#   datetime.date(1992, 12, 11),
#   datetime.date(1993, 12, 11),
#   'Staff',
#   datetime.date(1992, 12, 11),
#   datetime.date(1999, 12, 12)),
#  (15321,
#   40000,
#   datetime.date(1992, 5, 22),
#   datetime.date(1993, 5, 22),
#   'Engineer',
#   datetime.date(1992, 5, 22),
#   datetime.date(2001, 5, 22)),
#  (15321,
#   40000,
#   datetime.date(1992, 5, 22),
#   datetime.date(1993, 5, 22),
#   'Senior Engineer',
#   datetime.date(2001, 5, 22),
#   datetime.date(9999, 1, 1)),
#  (15329,
#   41839,
#   datetime.date(1997, 8, 16),
#   datetime.date(1998, 8, 16),
#   'Engineer',
#   datetime.date(1997, 8, 16),
#   datetime.date(9999, 1, 1)),
#  (15336,
#   62444,
#   datetime.date(1991, 3, 26),
#   datetime.date(1992, 3, 25),
#   'Senior Staff',
#   datetime.date(1996, 3, 25),
#   datetime.date(9999, 1, 1)),
#  (15336,
#   62444,
#   datetime.date(1991, 3, 26),
#   datetime.date(1992, 3, 25),
#   'Staff',
#   datetime.date(1991, 3, 26),
#   datetime.date(1996, 3, 25)),
#  (15342,
#   58617,
#   datetime.date(1992, 4, 25),
#   datetime.date(1993, 4, 25),
#   'Senior Staff',
#   datetime.date(1999, 4, 26),
#   datetime.date(9999, 1, 1)),
#  (15342,
#   58617,
#   datetime.date(1992, 4, 25),
#   datetime.date(1993, 4, 25),
#   'Staff',
#   datetime.date(1992, 4, 25),
#   datetime.date(1999, 4, 26)),
#  (15347,
#   69485,
#   datetime.date(1997, 3, 25),
#   datetime.date(1998, 3, 25),
#   'Senior Staff',
#   datetime.date(1997, 3, 25),
#   datetime.date(9999, 1, 1)),
#  (15350,
#   50037,
#   datetime.date(1990, 3, 23),
#   datetime.date(1990, 11, 28),
#   'Staff',
#   datetime.date(1990, 3, 23),
#   datetime.date(1990, 11, 28)),
#  (15355,
#   57428,
#   datetime.date(1987, 10, 9),
#   datetime.date(1988, 10, 8),
#   'Senior Engineer',
#   datetime.date(1987, 10, 9),
#   datetime.date(9999, 1, 1)),
#  (15371,
#   94288,
#   datetime.date(1988, 11, 5),
#   datetime.date(1989, 11, 5),
#   'Senior Staff',
#   datetime.date(1995, 11, 6),
#   datetime.date(9999, 1, 1)),
#  (15371,
#   94288,
#   datetime.date(1988, 11, 5),
#   datetime.date(1989, 11, 5),
#   'Staff',
#   datetime.date(1988, 11, 5),
#   datetime.date(1995, 11, 6)),
#  (15382,
#   66083,
#   datetime.date(1985, 12, 26),
#   datetime.date(1986, 12, 26),
#   'Senior Staff',
#   datetime.date(1992, 12, 26),
#   datetime.date(9999, 1, 1)),
#  (15382,
#   66083,
#   datetime.date(1985, 12, 26),
#   datetime.date(1986, 12, 26),
#   'Staff',
#   datetime.date(1985, 12, 26),
#   datetime.date(1992, 12, 26)),
#  (15385,
#   40000,
#   datetime.date(1987, 1, 17),
#   datetime.date(1988, 1, 17),
#   'Engineer',
#   datetime.date(1987, 1, 17),
#   datetime.date(1988, 4, 25)),
#  (15405,
#   40000,
#   datetime.date(1989, 7, 19),
#   datetime.date(1990, 7, 19),
#   'Assistant Engineer',
#   datetime.date(1989, 7, 19),
#   datetime.date(1996, 7, 19)),
#  (15405,
#   40000,
#   datetime.date(1989, 7, 19),
#   datetime.date(1990, 7, 19),
#   'Engineer',
#   datetime.date(1996, 7, 19),
#   datetime.date(9999, 1, 1)),
#  (15411,
#   40000,
#   datetime.date(1997, 2, 28),
#   datetime.date(1998, 2, 28),
#   'Engineer',
#   datetime.date(1997, 2, 28),
#   datetime.date(1998, 8, 14)),
#  (15443,
#   40000,
#   datetime.date(1990, 5, 18),
#   datetime.date(1991, 5, 18),
#   'Engineer',
#   datetime.date(1990, 5, 18),
#   datetime.date(1996, 5, 17)),
#  (15443,
#   40000,
#   datetime.date(1990, 5, 18),
#   datetime.date(1991, 5, 18),
#   'Senior Engineer',
#   datetime.date(1996, 5, 17),
#   datetime.date(9999, 1, 1)),
#  (15469,
#   71346,
#   datetime.date(1991, 6, 29),
#   datetime.date(1992, 6, 28),
#   'Senior Staff',
#   datetime.date(1999, 6, 29),
#   datetime.date(9999, 1, 1)),
#  (15469,
#   71346,
#   datetime.date(1991, 6, 29),
#   datetime.date(1992, 6, 28),
#   'Staff',
#   datetime.date(1991, 6, 29),
#   datetime.date(1999, 6, 29)),
#  (15470,
#   40693,
#   datetime.date(1996, 8, 8),
#   datetime.date(1997, 8, 8),
#   'Engineer',
#   datetime.date(1996, 8, 8),
#   datetime.date(9999, 1, 1)),
#  (15475,
#   40000,
#   datetime.date(1991, 9, 4),
#   datetime.date(1992, 9, 3),
#   'Senior Staff',
#   datetime.date(1998, 9, 4),
#   datetime.date(9999, 1, 1)),
#  (15475,
#   40000,
#   datetime.date(1991, 9, 4),
#   datetime.date(1992, 9, 3),
#   'Staff',
#   datetime.date(1991, 9, 4),
#   datetime.date(1998, 9, 4)),
#  (15481,
#   73147,
#   datetime.date(1993, 8, 23),
#   datetime.date(1994, 8, 23),
#   'Senior Staff',
#   datetime.date(1993, 8, 23),
#   datetime.date(9999, 1, 1)),
#  (15483,
#   40000,
#   datetime.date(1993, 9, 9),
#   datetime.date(1993, 10, 18),
#   'Staff',
#   datetime.date(1993, 9, 9),
#   datetime.date(1993, 10, 18)),
#  (15488,
#   40356,
#   datetime.date(1993, 4, 4),
#   datetime.date(1994, 4, 4),
#   'Engineer',
#   datetime.date(1993, 4, 4),
#   datetime.date(1995, 3, 25)),
#  (15524,
#   40000,
#   datetime.date(1997, 7, 20),
#   datetime.date(1998, 7, 20),
#   'Senior Staff',
#   datetime.date(2002, 7, 20),
#   datetime.date(9999, 1, 1)),
#  (15524,
#   40000,
#   datetime.date(1997, 7, 20),
#   datetime.date(1998, 7, 20),
#   'Staff',
#   datetime.date(1997, 7, 20),
#   datetime.date(2002, 7, 20)),
#  (15538,
#   40000,
#   datetime.date(1988, 2, 5),
#   datetime.date(1989, 2, 4),
#   'Senior Engineer',
#   datetime.date(1988, 2, 5),
#   datetime.date(9999, 1, 1)),
#  (15557,
#   58717,
#   datetime.date(1998, 1, 23),
#   datetime.date(1999, 1, 23),
#   'Engineer',
#   datetime.date(1998, 1, 23),
#   datetime.date(9999, 1, 1)),
#  (15559,
#   46835,
#   datetime.date(1990, 3, 11),
#   datetime.date(1991, 3, 11),
#   'Senior Staff',
#   datetime.date(1990, 3, 11),
#   datetime.date(9999, 1, 1)),
#  (15561,
#   56591,
#   datetime.date(1994, 1, 9),
#   datetime.date(1995, 1, 9),
#   'Engineer',
#   datetime.date(1994, 1, 9),
#   datetime.date(9999, 1, 1)),
#  (15564,
#   48503,
#   datetime.date(1999, 10, 3),
#   datetime.date(2000, 10, 2),
#   'Senior Staff',
#   datetime.date(1999, 10, 3),
#   datetime.date(9999, 1, 1)),
#  (15579,
#   40000,
#   datetime.date(1999, 1, 19),
#   datetime.date(2000, 1, 19),
#   'Engineer',
#   datetime.date(1999, 1, 19),
#   datetime.date(9999, 1, 1)),
#  (15587,
#   69785,
#   datetime.date(1989, 5, 1),
#   datetime.date(1990, 5, 1),
#   'Engineer',
#   datetime.date(1989, 5, 1),
#   datetime.date(1994, 5, 1)),
#  (15587,
#   69785,
#   datetime.date(1989, 5, 1),
#   datetime.date(1990, 5, 1),
#   'Senior Engineer',
#   datetime.date(1994, 5, 1),
#   datetime.date(9999, 1, 1)),
#  (15588,
#   40000,
#   datetime.date(1993, 10, 7),
#   datetime.date(1994, 10, 7),
#   'Senior Engineer',
#   datetime.date(1993, 10, 7),
#   datetime.date(9999, 1, 1)),
#  (15599,
#   63466,
#   datetime.date(1987, 2, 16),
#   datetime.date(1988, 2, 16),
#   'Senior Staff',
#   datetime.date(1996, 2, 16),
#   datetime.date(9999, 1, 1)),
#  (15599,
#   63466,
#   datetime.date(1987, 2, 16),
#   datetime.date(1988, 2, 16),
#   'Staff',
#   datetime.date(1987, 2, 16),
#   datetime.date(1996, 2, 16)),
#  (15628,
#   47624,
#   datetime.date(1992, 6, 11),
#   datetime.date(1993, 6, 11),
#   'Engineer',
#   datetime.date(1992, 6, 11),
#   datetime.date(1997, 2, 20)),
#  (15645,
#   54656,
#   datetime.date(1992, 4, 30),
#   datetime.date(1993, 4, 30),
#   'Senior Staff',
#   datetime.date(1997, 4, 30),
#   datetime.date(9999, 1, 1)),
#  (15645,
#   54656,
#   datetime.date(1992, 4, 30),
#   datetime.date(1993, 4, 30),
#   'Staff',
#   datetime.date(1992, 4, 30),
#   datetime.date(1997, 4, 30)),
#  (15650,
#   45913,
#   datetime.date(1997, 11, 16),
#   datetime.date(1998, 11, 16),
#   'Senior Engineer',
#   datetime.date(1997, 11, 16),
#   datetime.date(9999, 1, 1)),
#  (15651,
#   50313,
#   datetime.date(1985, 11, 22),
#   datetime.date(1986, 11, 22),
#   'Assistant Engineer',
#   datetime.date(1985, 11, 22),
#   datetime.date(1993, 11, 22)),
#  (15651,
#   50313,
#   datetime.date(1985, 11, 22),
#   datetime.date(1986, 11, 22),
#   'Engineer',
#   datetime.date(1993, 11, 22),
#   datetime.date(2001, 11, 22)),
#  (15651,
#   50313,
#   datetime.date(1985, 11, 22),
#   datetime.date(1986, 11, 22),
#   'Senior Engineer',
#   datetime.date(2001, 11, 22),
#   datetime.date(9999, 1, 1)),
#  (15652,
#   40000,
#   datetime.date(1994, 10, 20),
#   datetime.date(1995, 10, 20),
#   'Senior Staff',
#   datetime.date(1999, 10, 20),
#   datetime.date(9999, 1, 1)),
#  (15652,
#   40000,
#   datetime.date(1994, 10, 20),
#   datetime.date(1995, 10, 20),
#   'Staff',
#   datetime.date(1994, 10, 20),
#   datetime.date(1999, 10, 20)),
#  (15653,
#   54720,
#   datetime.date(1999, 11, 7),
#   datetime.date(2000, 8, 1),
#   'Staff',
#   datetime.date(1999, 11, 7),
#   datetime.date(2000, 8, 1)),
#  ...]

# %%
salaries_query = session.query(Salaries.emp_no, Salaries.salary, Salaries.from_date, Salaries.to_date).order_by(Salaries.salary).all()

titles_query = session.query(Titles.emp_no, Titles.title, Titles.from_date, Titles.to_date).order_by(Titles.emp_no).all()

# %%
salaries_df = pd.DataFrame(salaries_query, columns=['emp_no', 'salary', 'from_date', 'to_date'])
titles_df = pd.DataFrame(titles_query, columns=['emp_no', 'title', 'from_date', 'to_date'])

merge_df = pd.DataFrame(merge, columns=['emp_no', 'salary', 'salary_from_date', 'salary_to_date', 'title', 'title_from_date', 'title_to_date'])

# %%
salaries_df
# Out:
#         emp_no  salary   from_date     to_date
# 0        42589   40000  1989-03-07  1990-03-07
# 1        68253   40000  1993-01-23  1994-01-23
# 2        44127   40000  1996-10-22  1997-10-22
# 3        26876   40000  1997-02-04  1998-02-04
# 4        44124   40000  1998-05-26  1999-05-26
# ...        ...     ...         ...         ...
# 300019   37558  125469  1989-02-23  1990-02-23
# 300020  458302  126703  1998-10-05  1999-10-05
# 300021  444756  127041  1999-06-14  2000-06-13
# 300022   44188  127238  1991-03-16  1992-03-15
# 300023  205000  129492  1991-10-12  1992-10-11
#
# [300024 rows x 4 columns]

# %%
titles_df
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
merge_df
# Out:
#         emp_no  salary salary_from_date salary_to_date            title  \
# 0        10005   78228       1989-09-12     1990-09-12     Senior Staff
# 1        10005   78228       1989-09-12     1990-09-12            Staff
# 2        10010   72488       1996-11-24     1997-11-24         Engineer
# 3        10011   42365       1990-01-22     1991-01-22            Staff
# 4        10018   55881       1987-04-03     1988-04-02         Engineer
# ...        ...     ...              ...            ...              ...
# 443303  499972   41002       1989-11-23     1990-11-23  Senior Engineer
# 443304  499985   40000       1997-02-11     1998-02-11            Staff
# 443305  499987   52282       1999-12-21     2000-12-19            Staff
# 443306  499998   40000       1993-12-27     1994-12-27     Senior Staff
# 443307  499998   40000       1993-12-27     1994-12-27            Staff
#
#        title_from_date title_to_date
# 0           1996-09-12    9999-01-01
# 1           1989-09-12    1996-09-12
# 2           1996-11-24    9999-01-01
# 3           1990-01-22    1996-11-09
# 4           1987-04-03    1995-04-03
# ...                ...           ...
# 443303      1998-11-23    9999-01-01
# 443304      1997-02-11    9999-01-01
# 443305      1999-12-21    9999-01-01
# 443306      1998-12-27    9999-01-01
# 443307      1993-12-27    1998-12-27
#
# [443308 rows x 7 columns]

# %%
merge_df['salary'].min()
# Out:
# 40000

# %%
merge_df['salary'].max()
# Out:
# 129492

# %%
# The below each broken into bins of 4 years (i.e. <10, 10-14, 15-19, etc.)
bins = [0, 40000, 50000, 60000, 70000, 80000, 90000, 100000, 110000, 120000, 130000]

group_names = ['<40000', '40000-50000', '50000-60000', '60000-70000', '70000-80000', '80000-90000', '90000-100000', '100000-110000', '110000-120000', '120000-130000']

merge_df["Salary Range"] = pd.cut(merge_df["salary"], bins, labels=group_names)

employee_count_by_salary = merge_df.groupby('Salary Range')['salary'].count()

employee_count_by_salary
# Out:
# Salary Range
# <40000           140603
# 40000-50000       92892
# 50000-60000       85660
# 60000-70000       61235
# 70000-80000       36859
# 80000-90000       17679
# 90000-100000       6457
# 100000-110000      1597
# 110000-120000       289
# 120000-130000        37
# Name: salary, dtype: int64

# %%
employee_count_by_salary.plot(kind='bar', color='red')
plt.title("Number of Employees in Each Salary Range")
plt.ylabel("Salary Range")
plt.xlabel("Number of Employees")
plt.xticks(rotation=45)
# Show plot
plt.show()
plt.tight_layout()
plt.close()

# %%
salary_by_title = merge_df.groupby('title')['salary'].mean()

salary_by_title
# Out:
# title
# Assistant Engineer    48493.204786
# Engineer              48539.781423
# Manager               51531.041667
# Senior Engineer       48506.751806
# Senior Staff          58503.286614
# Staff                 58465.271904
# Technique Leader      48580.505772
# Name: salary, dtype: float64

# %%
salary_by_title.plot(kind='bar', color='red')
plt.title("Average Salary by Job Title")
plt.ylabel("Salary")
plt.xlabel("Job Title")
plt.xticks(rotation=45)
# Show plot
plt.show()
plt.tight_layout()
plt.close()

# %%
# Most employees earn 40k. As salary increases number of employees steadily decreases
# Staff and Senior Staff are earning more than engineers

# The second trend is unusual. The first trend is not unusual at all - most companies have a large number of employees at low-wage positions

# %%
merge_df.loc[merge_df['emp_no'] == 499942]
# Out:
#        emp_no  salary salary_from_date salary_to_date             title  \
# 55487  499942   40000       1998-03-28     1999-03-28  Technique Leader
#
#       title_from_date title_to_date Salary Range
# 55487      1998-03-28    9999-01-01       <40000
